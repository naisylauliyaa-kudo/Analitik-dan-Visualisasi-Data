# %% [markdown]
# # **Faktor-Faktor yang Mempengaruhi Popularitas Produk Kecantikan di Platform Sephora**
# ----
# Nama: Naisyla Auliya Rahmi Putri
# Kelas: B25
# NIM: 2509116078

# %% [markdown]
# # **Import Library**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px

# %% [markdown]
# #**Memuat Dataset**

# %%
file = "/content/drive/MyDrive/product_info.csv"

df = pd.read_csv(file)

df
# Out:
#      product_id                                       product_name  brand_id  \
# 0       P473671                            Fragrance Discovery Set      6342
# 1       P473668                            La Habana Eau de Parfum      6342
# 2       P473662                          Rainbow Bar Eau de Parfum      6342
# 3       P473660                               Kasbah Eau de Parfum      6342
# 4       P473658                          Purple Haze Eau de Parfum      6342
# ...         ...                                                ...       ...
# 8489    P467659                   Couture Clutch Eyeshadow Palette      1070
# 8490    P500874                              L'Homme Eau de Parfum      1070
# 8491    P504428                   Mon Paris Eau de Parfum Gift Set      1070
# 8492    P504448                           Y Eau de Parfum Gift Set      1070
# 8493    P505461  Candy Glaze Lip Gloss Stick Duo with Hyaluroni...      1070
#
#               brand_name  loves_count  rating  reviews             size  \
# 0                  19-69         6320  3.6364     11.0              NaN
# 1                  19-69         3827  4.1538     13.0   3.4 oz/ 100 mL
# 2                  19-69         3253  4.2500     16.0   3.4 oz/ 100 mL
# 3                  19-69         3018  4.4762     21.0   3.4 oz/ 100 mL
# 4                  19-69         2691  3.2308     13.0   3.4 oz/ 100 mL
# ...                  ...          ...     ...      ...              ...
# 8489  Yves Saint Laurent         2790  4.4286      7.0              NaN
# 8490  Yves Saint Laurent         2319  4.6367    556.0     2 oz / 60 mL
# 8491  Yves Saint Laurent         1475  5.0000      2.0              NaN
# 8492  Yves Saint Laurent          840     NaN      NaN              NaN
# 8493  Yves Saint Laurent          193     NaN      NaN  .11 oz / 3.2 mL
#
#                           variation_type                   variation_value  \
# 0                                    NaN                               NaN
# 1     Size + Concentration + Formulation                    3.4 oz/ 100 mL
# 2     Size + Concentration + Formulation                    3.4 oz/ 100 mL
# 3     Size + Concentration + Formulation                    3.4 oz/ 100 mL
# 4     Size + Concentration + Formulation                    3.4 oz/ 100 mL
# ...                                  ...                               ...
# 8489                                 NaN                               NaN
# 8490  Size + Concentration + Formulation  2 oz / 60 mL eau de parfum spray
# 8491                                 NaN                               NaN
# 8492                                 NaN                               NaN
# 8493                               Color                               NaN
#
#       ... online_only out_of_stock  sephora_exclusive  \
# 0     ...           1            0                  0
# 1     ...           1            0                  0
# 2     ...           1            0                  0
# 3     ...           1            0                  0
# 4     ...           1            0                  0
# ...   ...         ...          ...                ...
# 8489  ...           0            0                  0
# 8490  ...           0            0                  0
# 8491  ...           1            1                  0
# 8492  ...           1            0                  0
# 8493  ...           1            0                  1
#
#                                              highlights  primary_category  \
# 0     ['Unisex/ Genderless Scent', 'Warm &Spicy Scen...         Fragrance
# 1     ['Unisex/ Genderless Scent', 'Layerable Scent'...         Fragrance
# 2     ['Unisex/ Genderless Scent', 'Layerable Scent'...         Fragrance
# 3     ['Unisex/ Genderless Scent', 'Layerable Scent'...         Fragrance
# 4     ['Unisex/ Genderless Scent', 'Layerable Scent'...         Fragrance
# ...                                                 ...               ...
# 8489                                                NaN            Makeup
# 8490        ['Layerable Scent', 'Woody & Earthy Scent']         Fragrance
# 8491                                                NaN         Fragrance
# 8492                                                NaN         Fragrance
# 8493  ['Hyaluronic Acid', 'High Shine Finish', 'Plum...            Makeup
#
#       secondary_category  tertiary_category  child_count  child_max_price  \
# 0      Value & Gift Sets  Perfume Gift Sets            0              NaN
# 1                  Women            Perfume            2             85.0
# 2                  Women            Perfume            2             75.0
# 3                  Women            Perfume            2             75.0
# 4                  Women            Perfume            2             75.0
# ...                  ...                ...          ...              ...
# 8489                 Eye       Eye Palettes            0              NaN
# 8490                 Men            Cologne            1            129.0
# 8491   Value & Gift Sets  Perfume Gift Sets            0              NaN
# 8492   Value & Gift Sets  Cologne Gift Sets            0              NaN
# 8493                 Lip          Lip Gloss            0              NaN
#
#       child_min_price
# 0                 NaN
# 1                30.0
# 2                30.0
# 3                30.0
# 4                30.0
# ...               ...
# 8489              NaN
# 8490            129.0
# 8491              NaN
# 8492              NaN
# 8493              NaN
#
# [8494 rows x 27 columns]

# %% [markdown]
# #**Business Understanding**

# %% [markdown]
# ##**Business Objective**
#
# Dataset yang digunakan berisi 8.494 produk kecantikan dari platform Sephora dengan 27 kolom yang merepresentasikan karakteristik dan performa produk. Informasi yang tersedia meliputi identitas produk dan brand, harga, rating rata-rata pelanggan, jumlah review, jumlah loves sebagai indikator popularitas, kategori produk (primary, secondary, dan tertiary category), highlights, serta status ketersediaan produk.
#
# Permasalahan bisnis yang ingin dianalisis adalah perbedaan tingkat popularitas antar produk di dalam platform. Tidak semua produk dengan rating tinggi atau harga tertentu memiliki tingkat popularitas yang sama. Hal ini menunjukkan bahwa terdapat kombinasi faktor tertentu yang memengaruhi minat dan preferensi konsumen terhadap suatu produk.
#
# Tujuan analisis ini adalah untuk mengidentifikasi faktor-faktor utama yang berpengaruh terhadap popularitas produk, khususnya yang tercermin melalui jumlah loves. Hasil analisis diharapkan dapat memberikan insight bagi pengambilan keputusan strategis seperti penentuan harga, pengelompokan produk, serta optimalisasi strategi promosi berbasis data.

# %% [markdown]
# ##**Assess Situation**
#
# Dataset yang digunakan merupakan bagian product information dari dataset Sephora yang dikumpulkan. Dataset ini berisi informasi lebih dari 8.000 produk kecantikan yang mencakup nama produk, brand, rating, jumlah review, jumlah loves, kategori produk, serta berbagai fitur produk seperti highlights.
#
# Berdasarkan kondisi dataset, terdapat beberapa tantangan yang perlu diperhatikan. Pertama, terdapat kemungkinan adanya missing values pada beberapa kolom tertentu seperti harga diskon atau informasi tambahan produk. Kedua, variabel dalam dataset memiliki tipe data yang beragam (numerik, kategorikal, dan teks), sehingga memerlukan proses pembersihan dan penyesuaian sebelum dianalisis. Ketiga, terdapat perbedaan skala antar variabel numerik seperti harga dan jumlah loves yang cukup besar, sehingga dapat memengaruhi interpretasi hasil analisis. Selain itu, beberapa kolom seperti highlights berbentuk teks semi-terstruktur yang memerlukan pemrosesan tambahan apabila ingin dianalisis lebih lanjut.

# %% [markdown]
# ##**Analytic Goals**
#
# Berdasarkan permasalahan bisnis yang telah diidentifikasi, tujuan analitik dari penelitian ini adalah untuk:
#
# 1. Menganalisis distribusi variabel utama seperti harga, rating, jumlah review, dan jumlah loves guna memahami karakteristik umum produk dalam dataset.
# 2. Mengidentifikasi hubungan antara variabel numerik (harga, rating, jumlah review) dengan jumlah loves sebagai indikator popularitas produk.
# 3. Membandingkan tingkat popularitas antar kategori dan brand untuk mengetahui apakah terdapat pola tertentu yang memengaruhi minat konsumen.
# 4. Menentukan faktor-faktor yang memiliki pengaruh paling signifikan terhadap popularitas produk berdasarkan hasil analisis eksploratif dan korelasi.
#
# Hasil dari analisis ini diharapkan mampu memberikan pemahaman berbasis data mengenai faktor yang mendorong popularitas produk di platform e-commerce.

# %% [markdown]
# ##**Project Plan**
#
# Rencana pengerjaan proyek ini meliputi:
#
# 1. Memahami struktur dataset serta tipe data setiap variabel
# 2. Melakukan pembersihan data (menangani missing values dan inkonsistensi)
# 3. Melakukan eksplorasi data untuk melihat distribusi harga, rating, jumlah review, dan loves
# 4. Menganalisis hubungan antar variabel numerik serta perbandingan berdasarkan kategori dan brand
# 5. Menginterpretasikan hasil analisis untuk mengidentifikasi faktor yang memengaruhi popularitas produk dan menyusun insight bisnis

# %% [markdown]
# # **Data Understanding**

# %% [markdown]
# ## **Memuat Dataset**

# %%
file = '/content/drive/MyDrive/product_info.csv'

df = pd.read_csv(file)

df
# Out:
#      product_id                                       product_name  brand_id  \
# 0       P473671                            Fragrance Discovery Set      6342
# 1       P473668                            La Habana Eau de Parfum      6342
# 2       P473662                          Rainbow Bar Eau de Parfum      6342
# 3       P473660                               Kasbah Eau de Parfum      6342
# 4       P473658                          Purple Haze Eau de Parfum      6342
# ...         ...                                                ...       ...
# 8489    P467659                   Couture Clutch Eyeshadow Palette      1070
# 8490    P500874                              L'Homme Eau de Parfum      1070
# 8491    P504428                   Mon Paris Eau de Parfum Gift Set      1070
# 8492    P504448                           Y Eau de Parfum Gift Set      1070
# 8493    P505461  Candy Glaze Lip Gloss Stick Duo with Hyaluroni...      1070
#
#               brand_name  loves_count  rating  reviews             size  \
# 0                  19-69         6320  3.6364     11.0              NaN
# 1                  19-69         3827  4.1538     13.0   3.4 oz/ 100 mL
# 2                  19-69         3253  4.2500     16.0   3.4 oz/ 100 mL
# 3                  19-69         3018  4.4762     21.0   3.4 oz/ 100 mL
# 4                  19-69         2691  3.2308     13.0   3.4 oz/ 100 mL
# ...                  ...          ...     ...      ...              ...
# 8489  Yves Saint Laurent         2790  4.4286      7.0              NaN
# 8490  Yves Saint Laurent         2319  4.6367    556.0     2 oz / 60 mL
# 8491  Yves Saint Laurent         1475  5.0000      2.0              NaN
# 8492  Yves Saint Laurent          840     NaN      NaN              NaN
# 8493  Yves Saint Laurent          193     NaN      NaN  .11 oz / 3.2 mL
#
#                           variation_type                   variation_value  \
# 0                                    NaN                               NaN
# 1     Size + Concentration + Formulation                    3.4 oz/ 100 mL
# 2     Size + Concentration + Formulation                    3.4 oz/ 100 mL
# 3     Size + Concentration + Formulation                    3.4 oz/ 100 mL
# 4     Size + Concentration + Formulation                    3.4 oz/ 100 mL
# ...                                  ...                               ...
# 8489                                 NaN                               NaN
# 8490  Size + Concentration + Formulation  2 oz / 60 mL eau de parfum spray
# 8491                                 NaN                               NaN
# 8492                                 NaN                               NaN
# 8493                               Color                               NaN
#
#       ... online_only out_of_stock  sephora_exclusive  \
# 0     ...           1            0                  0
# 1     ...           1            0                  0
# 2     ...           1            0                  0
# 3     ...           1            0                  0
# 4     ...           1            0                  0
# ...   ...         ...          ...                ...
# 8489  ...           0            0                  0
# 8490  ...           0            0                  0
# 8491  ...           1            1                  0
# 8492  ...           1            0                  0
# 8493  ...           1            0                  1
#
#                                              highlights  primary_category  \
# 0     ['Unisex/ Genderless Scent', 'Warm &Spicy Scen...         Fragrance
# 1     ['Unisex/ Genderless Scent', 'Layerable Scent'...         Fragrance
# 2     ['Unisex/ Genderless Scent', 'Layerable Scent'...         Fragrance
# 3     ['Unisex/ Genderless Scent', 'Layerable Scent'...         Fragrance
# 4     ['Unisex/ Genderless Scent', 'Layerable Scent'...         Fragrance
# ...                                                 ...               ...
# 8489                                                NaN            Makeup
# 8490        ['Layerable Scent', 'Woody & Earthy Scent']         Fragrance
# 8491                                                NaN         Fragrance
# 8492                                                NaN         Fragrance
# 8493  ['Hyaluronic Acid', 'High Shine Finish', 'Plum...            Makeup
#
#       secondary_category  tertiary_category  child_count  child_max_price  \
# 0      Value & Gift Sets  Perfume Gift Sets            0              NaN
# 1                  Women            Perfume            2             85.0
# 2                  Women            Perfume            2             75.0
# 3                  Women            Perfume            2             75.0
# 4                  Women            Perfume            2             75.0
# ...                  ...                ...          ...              ...
# 8489                 Eye       Eye Palettes            0              NaN
# 8490                 Men            Cologne            1            129.0
# 8491   Value & Gift Sets  Perfume Gift Sets            0              NaN
# 8492   Value & Gift Sets  Cologne Gift Sets            0              NaN
# 8493                 Lip          Lip Gloss            0              NaN
#
#       child_min_price
# 0                 NaN
# 1                30.0
# 2                30.0
# 3                30.0
# 4                30.0
# ...               ...
# 8489              NaN
# 8490            129.0
# 8491              NaN
# 8492              NaN
# 8493              NaN
#
# [8494 rows x 27 columns]

# %% [markdown]
# ## **Deskripsi Data**

# %% [markdown]
# ### **Informasi Dasar**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8494 entries, 0 to 8493
# Data columns (total 27 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   product_id          8494 non-null   object
#  1   product_name        8494 non-null   object
#  2   brand_id            8494 non-null   int64
#  3   brand_name          8494 non-null   object
#  4   loves_count         8494 non-null   int64
#  5   rating              8216 non-null   float64
#  6   reviews             8216 non-null   float64
#  7   size                6863 non-null   object
#  8   variation_type      7050 non-null   object
#  9   variation_value     6896 non-null   object
#  10  variation_desc      1250 non-null   object
#  11  ingredients         7549 non-null   object
#  12  price_usd           8494 non-null   float64
#  13  value_price_usd     451 non-null    float64
#  14  sale_price_usd      270 non-null    float64
#  15  limited_edition     8494 non-null   int64
#  16  new                 8494 non-null   int64
#  17  online_only         8494 non-null   int64
#  18  out_of_stock        8494 non-null   int64
#  19  sephora_exclusive   8494 non-null   int64
#  20  highlights          6287 non-null   object
#  21  primary_category    8494 non-null   object
#  22  secondary_category  8486 non-null   object
#  23  tertiary_category   7504 non-null   object
#  24  child_count         8494 non-null   int64
#  25  child_max_price     2754 non-null   float64
#  26  child_min_price     2754 non-null   float64
# dtypes: float64(7), int64(8), object(12)
# memory usage: 1.7+ MB

# %% [markdown]
# Berdasarkan data di atas, dapat diketahui bahwa dataset ini memiliki 8494 Baris dan 27 Kolom

# %% [markdown]
# ### **Informasi Lanjutan**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8494 entries, 0 to 8493
# Data columns (total 27 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   product_id          8494 non-null   object
#  1   product_name        8494 non-null   object
#  2   brand_id            8494 non-null   int64
#  3   brand_name          8494 non-null   object
#  4   loves_count         8494 non-null   int64
#  5   rating              8216 non-null   float64
#  6   reviews             8216 non-null   float64
#  7   size                6863 non-null   object
#  8   variation_type      7050 non-null   object
#  9   variation_value     6896 non-null   object
#  10  variation_desc      1250 non-null   object
#  11  ingredients         7549 non-null   object
#  12  price_usd           8494 non-null   float64
#  13  value_price_usd     451 non-null    float64
#  14  sale_price_usd      270 non-null    float64
#  15  limited_edition     8494 non-null   int64
#  16  new                 8494 non-null   int64
#  17  online_only         8494 non-null   int64
#  18  out_of_stock        8494 non-null   int64
#  19  sephora_exclusive   8494 non-null   int64
#  20  highlights          6287 non-null   object
#  21  primary_category    8494 non-null   object
#  22  secondary_category  8486 non-null   object
#  23  tertiary_category   7504 non-null   object
#  24  child_count         8494 non-null   int64
#  25  child_max_price     2754 non-null   float64
#  26  child_min_price     2754 non-null   float64
# dtypes: float64(7), int64(8), object(12)
# memory usage: 1.7+ MB

# %% [markdown]
# 1. product_id: Jumlah data:8.494 Tipe data: object Deskripsi:ID unik untuk setiap produk
# 2. product_name: Jumlah data: 8.494 Tipe data: object Deskripsi: Nama produk yang dijual
# 3. brand_id: Jumlah data: 8.494 Tipe data: object Deskripsi: Nama brand dari produk
# 4. brand_name: Jumlah data: 8.494 Tipe data: int64 Deskripsi: Jumlah pengguna yang menyukai (favorite/love) produk tersebut.
# 5. loves_count: Jumlah data: 8.494 Tipe data: int64
# Deskripsi: Jumlah pengguna yang menyukai (favorite/love) produk tersebut.
# 6. rating: Jumlah data: 8.216 Tipe data: float64 Deskripsi: Nilai rating rata-rata produk yang diberikan oleh pengguna.
# 7. reviews: Jumlah data: 8.216 Tipe data: float64 Deskripsi: Jumlah review yang diberikan oleh pengguna.
# 8. size: Jumlah data: 6.863 Tipe data: object Deskripsi: Ukuran atau volume produk.
# 9. variation_type: Jumlah data: 7.050 Tipe data: object Deskripsi: Jenis variasi produk (misalnya warna, ukuran, dll).
# 10. variation_value: Jumlah data: 6.896 Tipe data: object Deskripsi: Nilai variasi produk (contoh: shade tertentu).
# 11. variation_desc: Jumlah data: 1.250 Tipe data: object Deskripsi: Deskripsi tambahan terkait variasi produk.
# 12. ingredients: Jumlah data: 7.549 Tipe data: object Deskripsi: Daftar bahan kandungan produk.
# 13. price_usd: Jumlah data: 8.494 Tipe data: float64 Deskripsi: Harga utama produk dalam USD.
# 14. value_price_usd: Jumlah data: 451 Tipe data: float64 Deskripsi: Harga nilai (value price), biasanya untuk bundling atau ukuran khusus.
# 15. sale_price_usd: Jumlah data: 270 Tipe data: float64 Deskripsi: Harga diskon produk jika sedang promo.
# 16. limited_edition: Jumlah data: 8.494 Tipe data: int64 Deskripsi: Penanda apakah produk edisi terbatas (1 = ya, 0 = tidak).
# 17. new: Jumlah data: 8.494 Tipe data: int64 Deskripsi: Penanda apakah produk termasuk produk baru (1 = ya, 0 = tidak).
# 18. online_only: Jumlah data: 8.494 Tipe data: int64 Deskripsi: Penanda apakah produk hanya tersedia secara online (1 = ya, 0 = tidak).
# 19. out_of_stock: Jumlah data: 8.494 Tipe data: int64 Deskripsi: Penanda apakah produk sedang habis stok (1 = ya, 0 = tidak).
# 20. Sephora_exclusive: Jumlah data: 8.494 Tipe data: int64 Deskripsi: Penanda apakah produk eksklusif dijual di Sephora (1 = ya, 0 = tidak).
# 21. highlights: Jumlah data: 6.287 Tipe data: object Deskripsi: Fitur unggulan atau klaim utama produk (misalnya vegan, cruelty-free, dll).
# 22. primary_category:
# Jumlah data: 8.494 Tipe data: object Deskripsi: Kategori utama produk.
# 23. secondary_category: Jumlah data: 8.486 Tipe data: object Deskripsi: Sub-kategori dari kategori utama.
# 24. tertiary_category: Jumlah data: 7.504 Tipe data: object Deskripsi: Kategori tingkat ketiga (lebih spesifik).
# 25. child_count: Jumlah data: 8.494 Tipe data: int64 Deskripsi: Jumlah variasi turunan dari suatu produk.
# 26. child_max_price:
# Jumlah data: 2.754 Tipe data: float64 Deskripsi: Harga maksimum dari variasi produk.
# 27. child_min_price: Jumlah data: 2.754
# Tipe data: float64 Deskripsi: Harga minimum dari variasi produk.

# %% [markdown]
# ### **Informasi Statistik Deskriptif**

# %%
df.describe(include='all')
# Out:
#        product_id   product_name     brand_id          brand_name  \
# count        8494           8494  8494.000000                8494
# unique       8494           8415          NaN                 304
# top       P505461  Discovery Set          NaN  SEPHORA COLLECTION
# freq            1              3          NaN                 352
# mean          NaN            NaN  5422.440546                 NaN
# std           NaN            NaN  1709.595957                 NaN
# min           NaN            NaN  1063.000000                 NaN
# 25%           NaN            NaN  5333.000000                 NaN
# 50%           NaN            NaN  6157.500000                 NaN
# 75%           NaN            NaN  6328.000000                 NaN
# max           NaN            NaN  8020.000000                 NaN
#
#          loves_count       rating       reviews           size variation_type  \
# count   8.494000e+03  8216.000000   8216.000000           6863           7050
# unique           NaN          NaN           NaN           2055              7
# top              NaN          NaN           NaN  1.7 oz/ 50 mL           Size
# freq             NaN          NaN           NaN            500           4043
# mean    2.917957e+04     4.194513    448.545521            NaN            NaN
# std     6.609212e+04     0.516694   1101.982529            NaN            NaN
# min     0.000000e+00     1.000000      1.000000            NaN            NaN
# 25%     3.758000e+03     3.981725     26.000000            NaN            NaN
# 50%     9.880000e+03     4.289350    122.000000            NaN            NaN
# 75%     2.684125e+04     4.530525    418.000000            NaN            NaN
# max     1.401068e+06     5.000000  21281.000000            NaN            NaN
#
#        variation_value  ...  online_only out_of_stock  sephora_exclusive  \
# count             6896  ...  8494.000000  8494.000000        8494.000000
# unique            2729  ...          NaN          NaN                NaN
# top      1.7 oz/ 50 mL  ...          NaN          NaN                NaN
# freq               374  ...          NaN          NaN                NaN
# mean               NaN  ...     0.219096     0.073699           0.279374
# std                NaN  ...     0.413658     0.261296           0.448718
# min                NaN  ...     0.000000     0.000000           0.000000
# 25%                NaN  ...     0.000000     0.000000           0.000000
# 50%                NaN  ...     0.000000     0.000000           0.000000
# 75%                NaN  ...     0.000000     0.000000           1.000000
# max                NaN  ...     1.000000     1.000000           1.000000
#
#                                  highlights  primary_category  \
# count                                  6287              8494
# unique                                 4417                 9
# top     ['Layerable Scent', 'Floral Scent']          Skincare
# freq                                     64              2420
# mean                                    NaN               NaN
# std                                     NaN               NaN
# min                                     NaN               NaN
# 25%                                     NaN               NaN
# 50%                                     NaN               NaN
# 75%                                     NaN               NaN
# max                                     NaN               NaN
#
#         secondary_category  tertiary_category  child_count  child_max_price  \
# count                 8486               7504  8494.000000      2754.000000
# unique                  41                118          NaN              NaN
# top                  Women            Perfume          NaN              NaN
# freq                   875                568          NaN              NaN
# mean                   NaN                NaN     1.631622        53.792023
# std                    NaN                NaN     5.379470        58.765894
# min                    NaN                NaN     0.000000         3.000000
# 25%                    NaN                NaN     0.000000        22.000000
# 50%                    NaN                NaN     0.000000        32.000000
# 75%                    NaN                NaN     1.000000        59.000000
# max                    NaN                NaN   105.000000       570.000000
#
#         child_min_price
# count       2754.000000
# unique              NaN
# top                 NaN
# freq                NaN
# mean          39.665802
# std           38.685720
# min            3.000000
# 25%           19.000000
# 50%           28.000000
# 75%           42.000000
# max          400.000000
#
# [11 rows x 27 columns]

# %% [markdown]
# 1. Count (Kelengkapan Data) Berdasarkan hasil dari statistik deskriptif, dataset terdiri dari 8.494 baris data dengan 27 kolom.
# Beberapa kolom memiliki nilai yang tidak lengkap (missing values), yang dapat diidentifikasi melalui perbedaan antara total baris (8.494) dan nilai count masing-masing variabel.
# *   rating dan reviews memiliki 8.216 data valid (missing 278 data).
# *   size memiliki 6.863 data (missing 1.631 data).
# *   variation_type berisi 7.050 data, sehingga terdapat 1.444 data yang hilang.
# *   variation_value berisi 6.896 data, sehingga terdapat 1.598 data yang hilang.
# *   highlights berisi 6.287 data, sehingga terdapat 2.207 data yang hilang.
# *   secondary_category berisi 8.486 data, sehingga terdapat 8 data yang hilang.
# *   tertiary_category berisi 7.504 data, sehingga terdapat 990 data yang hilang.
# *   child_max_price berisi 2.754 data, sehingga terdapat 5.740 data yang hilang.
# *  child_min_price berisi 2.754 data, sehingga terdapat 5.740 data yang hilang.
#
# Kesimpulan: selain dari yang sudah ditulis diatas, kolom yang lain sudah memiliki data lengap yaitu dengan jumlah 8.494.
#
# ---
#
# Statistik Deskriptif Variabel Numerik
#
# 1. Price (price_usd)
#
# - Mean: 51,66
# - Median: 35
# - Standar Deviasi: 53,67
# - Minimum: 3
# - Maksimum: 1.900
#
# Nilai rata-rata harga sebesar 51,66 menunjukkan bahwa secara umum produk berada pada rentang harga menengah. Namun median yang lebih rendah, yaitu 35, mengindikasikan bahwa sebagian besar produk sebenarnya memiliki harga di bawah nilai rata-rata tersebut. Standar deviasi yang cukup besar (53,67) menunjukkan variasi harga yang tinggi antar produk. Rentang harga yang sangat lebar, dari 3 hingga 1.900, menandakan adanya produk dengan harga sangat tinggi yang memengaruhi nilai rata-rata.
#
# 2. Loves Count
#
# - Mean: 29.179
# - Median: 9.880
# - Standar Deviasi: 66.092,12
# - Minimum: 0
# - Maksimum: 1.401.068
#
# Rata-rata jumlah likes sebesar 29.179 menunjukkan tingkat ketertarikan pengguna yang cukup tinggi secara umum. Namun median yang jauh lebih rendah dibandingkan mean mengindikasikan bahwa hanya sebagian kecil produk yang memiliki jumlah likes sangat besar. Standar deviasi yang sangat tinggi memperlihatkan bahwa penyebaran data tidak merata, sehingga terdapat perbedaan popularitas yang signifikan antar produk.
#
# 3. Rating
#
# - Mean: 4,19
# - Median: 4,29
# - Standar Deviasi: 0,52
# - Minimum: 1
# - Maksimum: 5
#
# Nilai rata-rata rating sebesar 4,19 menunjukkan bahwa mayoritas produk memiliki penilaian yang baik. Median yang sedikit lebih tinggi dari mean menunjukkan distribusi rating relatif stabil dan tidak terlalu dipengaruhi oleh nilai ekstrem. Standar deviasi yang kecil (0,52) menandakan bahwa variasi penilaian antar produk tidak terlalu besar dan sebagian besar rating berada di sekitar nilai 4.
#
# 4. Reviews
#
# - Mean: 448
# - Median: 122
# - Standar Deviasi: 1.101,98
# - Minimum: 1
# - Maksimum: 21.281
#
# Rata-rata jumlah review sebesar 448 menunjukkan bahwa produk dalam dataset memiliki tingkat partisipasi pengguna yang cukup baik. Namun median yang jauh lebih rendah menunjukkan bahwa sebagian besar produk memiliki jumlah ulasan yang relatif sedikit. Standar deviasi yang tinggi mengindikasikan adanya produk tertentu dengan jumlah review sangat besar yang menyebabkan distribusi data menjadi tidak merata.
#
# 5. Value Price (451 data tersedia)
#
# - Mean: 91,17
# - Median: 67
# - Standar Deviasi: 79,20
# - Minimum: 0
# - Maksimum: 617
#
# Nilai rata-rata value price lebih tinggi dibandingkan price_usd, yang menunjukkan bahwa produk dalam kategori ini umumnya memiliki harga lebih besar, kemungkinan berupa paket atau bundling produk. Standar deviasi yang tinggi menandakan variasi harga yang cukup besar dalam kategori ini.
#
# 6. Sale Price (270 data tersedia)
#
# - Mean: 20,21
# - Median: 14
# - Standar Deviasi: 24,33
# - Minimum: 1,75
# - Maksimum: 320
#
# Harga diskon memiliki rata-rata yang relatif rendah dibandingkan harga normal. Median yang lebih kecil dari mean menunjukkan adanya beberapa produk dengan diskon sangat tinggi. Standar deviasi yang cukup besar menunjukkan variasi potongan harga antar produk.
#
# 7. Child Count
#
# - Mean: 1,63
# - Median: 0
# - Standar Deviasi: 5,38
# - Minimum: 0
# - Maksimum: 105
#
# Rata-rata jumlah variasi produk sebesar 1,63 menunjukkan bahwa sebagian besar produk tidak memiliki banyak variasi. Median bernilai 0 mengindikasikan bahwa mayoritas produk tidak memiliki turunan atau varian tambahan. Namun nilai maksimum yang mencapai 105 menunjukkan adanya beberapa produk dengan variasi sangat banyak.
#
# Kesimpulan:
# Berdasarkan hasil analisis terhadap 8.494 data produk, terlihat bahwa variasi terbesar terdapat pada harga, jumlah likes, dan jumlah review. Perbedaan yang cukup besar antara nilai rata-rata dan median pada beberapa variabel menunjukkan bahwa distribusi data tidak merata dan dipengaruhi oleh sejumlah produk dengan nilai yang sangat tinggi.
#
# Sementara itu, variabel rating menunjukkan pola yang lebih stabil dengan rata-rata yang tinggi dan penyebaran yang kecil, sehingga dapat disimpulkan bahwa sebagian besar produk memiliki penilaian yang baik. Secara umum, dataset ini menunjukkan keberagaman pada aspek harga dan popularitas, namun relatif konsisten pada aspek kualitas berdasarkan rating.

# %% [markdown]
# ## **Verifikasi Kualitas Data**

# %% [markdown]
# ### **Data Type Check**

# %%
df.dtypes
# Out:
# product_id             object
# product_name           object
# brand_id                int64
# brand_name             object
# loves_count             int64
# rating                float64
# reviews               float64
# size                   object
# variation_type         object
# variation_value        object
# variation_desc         object
# ingredients            object
# price_usd             float64
# value_price_usd       float64
# sale_price_usd        float64
# limited_edition         int64
# new                     int64
# online_only             int64
# out_of_stock            int64
# sephora_exclusive       int64
# highlights             object
# primary_category       object
# secondary_category     object
# tertiary_category      object
# child_count             int64
# child_max_price       float64
# child_min_price       float64
# dtype: object

# %% [markdown]
# Meskipun secara teknis seluruh kolom sudah terbaca sesuai format dasarnya, masih terdapat ruang optimasi pada tipe data. Kolom brand_id sebaiknya diubah menjadi tipe object atau category karena berfungsi sebagai identitas, bukan sebagai nilai numerik untuk perhitungan. Selain itu, kolom biner seperti limited_edition, new, online_only, out_of_stock, dan sephora_exclusive akan lebih tepat jika diubah menjadi tipe bool, agar tidak terbaca sebagai data numerik murni dalam analisis statistik dan lebih merepresentasikan kondisi True/False secara konseptual.

# %% [markdown]
# ### **Incosistent Values**

# %%
print(df['product_id'].unique())
# Out:
# ['P473671' 'P473668' 'P473662' ... 'P504428' 'P504448' 'P505461']

# %% [markdown]
# Kolom product_id menunjukkan bahwa setiap produk memiliki identitas unik dengan format yang konsisten. Pola penulisannya seragam dan tidak terlihat adanya variasi struktur atau duplikasi pada data yang ditampilkan. Hal ini menunjukkan bahwa kolom tersebut sudah tertata dengan baik dan dapat digunakan sebagai primary key dalam dataset.

# %%
print(df['product_name'].unique())
# Out:
# ['Fragrance Discovery Set' 'La Habana Eau de Parfum'
#  'Rainbow Bar Eau de Parfum' ... 'Mon Paris Eau de Parfum Gift Set'
#  'Y Eau de Parfum Gift Set'
#  'Candy Glaze Lip Gloss Stick Duo with Hyaluronic Acid']

# %% [markdown]
# Kolom product_name berisi nama produk yang cukup deskriptif dan beragam. Tidak terlihat adanya nilai kosong pada data yang ditampilkan. Namun demikian, tetap diperlukan pengecekan lebih lanjut untuk memastikan tidak terdapat duplikasi nama dengan perbedaan kecil seperti tambahan spasi atau variasi huruf kapital.

# %%
print(df['brand_name'].unique())
# Out:
# ['19-69' '54 Thrones' 'ABBOTT' 'Acqua di Parma' 'adwoa beauty' 'AERIN'
#  'Algenist' 'Alpha-H' 'alpyn beauty' 'ALTERNA Haircare' 'Ami Colé' 'amika'
#  'Anastasia Beverly Hills' 'Aquis' 'Armani Beauty' 'Artist Couture'
#  'Atelier Cologne' 'Augustinus Bader' 'Azzaro' 'bareMinerals' 'BeautyBio'
#  'beautyblender' 'belif' 'Benefit Cosmetics' 'BERDOUES' 'Bio Ionic'
#  'Biossance' 'Blinc' 'Bobbi Brown' 'Bon Parfumeur' 'BondiBoost'
#  'Boy Smells' 'BREAD BEAUTY SUPPLY' 'Briogeo' 'Bumble and bumble'
#  'BURBERRY' 'Buxom' 'By Rosie Jane' 'caliray' 'Calvin Klein' 'CANOPY'
#  'Capri Blue' 'Carolina Herrera' 'Caudalie' 'CAY SKIN' 'Ceremonia'
#  'CHANEL' 'Charlotte Tilbury' 'Chloé' 'Christian Louboutin'
#  'Christophe Robin' 'Cinema Secrets' 'Clarins' 'CLEAN RESERVE' 'CLINIQUE'
#  'COLOR WOW' 'Commodity' 'Community Sixty-Six' 'COOLA' 'Crown Affair'
#  'Curlsmith' 'dae' 'DAMDAM' 'Dame' 'Danessa Myricks Beauty'
#  'Deborah Lippmann' 'DedCool' 'DEREK LAM 10 CROSBY' 'DERMAFLASH'
#  'Dermalogica' 'Dior' 'Dolce&Gabbana' 'DOMINIQUE COSMETICS' 'Donna Karan'
#  'dpHUE' 'Dr. Barbara Sturm' 'Dr. Brandt Skincare'
#  'Dr. Dennis Gross Skincare' 'Dr. Jart+'
#  'Dr. Lara Devgan Scientific Beauty' 'Dr. Zenovia Skincare'
#  'Drunk Elephant' 'Drybar' 'DUO' 'EADEM' 'Eight & Bob' 'Ellis Brooklyn'
#  'Erno Laszlo' 'Estée Lauder' 'Evian' 'Fable & Mane' 'FaceGym' 'Farmacy'
#  'Fashion Fair' 'Fenty Beauty by Rihanna' 'Fenty Skin' 'First Aid Beauty'
#  'Flora + Bast' 'Floral Street' 'FOREO' 'FORVR Mood' 'Freck Beauty'
#  'fresh' 'ghd' 'Gisou' 'Givenchy' 'Glamnetic' 'GLO Science' 'Glossier'
#  'Glow Recipe' 'Good Dye Young' 'Google' 'goop' 'Grace Eleyae'
#  'Grande Cosmetics' 'Gucci' 'GUERLAIN' 'GXVE BY GWEN STEFANI' 'HABIT'
#  'Hanni' 'HAUS LABS BY LADY GAGA' 'Herbivore' 'HERETIC' 'HERMÈS'
#  'Hourglass' 'House of Lashes' 'HUDA BEAUTY' 'HUM Nutrition' 'Hyper Skin'
#  'Iconic London' 'IGK' 'ILIA' 'iluminage' 'INC.redible'
#  'iNNBEAUTY PROJECT' 'innisfree' 'Isle of Paradise' 'IT Cosmetics'
#  'Jack Black' 'Jillian Dempsey' 'JIMMY CHOO' 'JLo Beauty'
#  'Jo Malone London' 'Josie Maran' 'Jouer Cosmetics' 'Juicy Couture'
#  'Juliette Has a Gun' 'JVN' 'K18 Biomimetic Hairscience' 'Kaja'
#  'Kate McLeod' 'Kate Somerville' 'KAYALI' 'Kérastase' "Kiehl's Since 1851"
#  'KILIAN Paris' 'Koh Gen Do' 'Kopari' 'KORA Organics' 'KORRES' 'Kosas'
#  'Kulfi' 'KVD Beauty' "L'Occitane" "L'Oreal Professionnel" 'La Mer'
#  'Lancôme' 'LANEIGE' 'Laura Mercier' 'LAWLESS' 'lilah b.' 'Lilly Lashes'
#  'Living Proof' 'LYS Beauty' 'MACRENE actives' 'Maison Louis Marie'
#  'Maison Margiela' 'MAKE UP FOR EVER' 'MAKEUP BY MARIO' 'MARA'
#  'Marc Jacobs Fragrances' 'Mario Badescu' 'maude' 'Melanin Haircare'
#  'Melt Cosmetics' 'MERIT' 'MILK MAKEUP' 'Mizani' 'Montblanc' 'Moon Juice'
#  'Moroccanoil' 'Mount Lai' 'Mugler' 'Murad' 'NAILS INC.'
#  'Narciso Rodriguez' 'NARS' 'Natasha Denona' 'Naturally Serious'
#  'Nécessaire' 'NEST New York' 'NUDESTIX' 'NuFACE' 'Nutrafol' 'Olaplex'
#  'OLEHENRIKSEN' 'ONE/SIZE by Patrick Starrr' 'Oribe' 'Origins' 'OTHERLAND'
#  'OUAI' 'Overose' 'Paco Rabanne' 'PAT McGRATH LABS' 'PATRICK TA'
#  'PATTERN by Tracee Ellis Ross' "Paula's Choice" 'Peace Out'
#  'Peter Thomas Roth' 'philosophy' 'PHLUR' 'PMD' 'Prada' 'Prima'
#  'PROVEN Skincare' 'Pureology' 'Rahua' 'Ralph Lauren' 'RANAVAT'
#  'Rare Beauty by Selena Gomez' 'REFY' 'REN Clean Skincare' 'RIES'
#  'rms beauty' 'ROSE INC' 'ROSE Ingleton MD' 'Rosebud Perfume Co.'
#  'Rossano Ferretti Parma' 'Saie' 'Saint Jane Beauty' 'SEPHORA COLLECTION'
#  'Sephora Favorites' 'Shani Darden Skin Care' 'Shiseido' 'shu uemura'
#  'SIMIHAZE BEAUTY' 'SK-II' 'Skin Laundry' 'Skinfix' 'SKYLAR' 'Slip'
#  'Smashbox' 'SOBEL SKIN Rx' 'Sol de Janeiro' 'Soleil Toujours'
#  'St. Tropez' 'stila' 'StriVectin' 'Sulwhasoo' 'Summer Fridays'
#  'SUNDAY II SUNDAY' 'Sunday Riley' 'Supergoop!' 'Susteau' 'T3' 'TAN-LUXE'
#  'tarte' 'Tata Harper' 'Tatcha' 'The 7 Virtues' 'The INKEY List'
#  'The Maker' 'The Nue Co.' 'The Ordinary' 'The Original MakeUp Eraser'
#  'The Outset' 'The Phluid Project' 'TOCCA' 'TOM FORD' 'Too Faced'
#  'Topicals' 'Touchland' 'Tower 28 Beauty' 'TULA Skincare' 'TWEEZERMAN'
#  'Urban Decay' 'Valentino' 'Vegamour' 'Velour Lashes' 'Verb' 'Versace'
#  'Viktor&Rolf' 'Violet Voss' 'Viori' 'Virtue' 'Viseart' 'VOLUSPA'
#  'Wander Beauty' 'WASO' 'Westman Atelier' 'Wishful'
#  'World of Chris Collins' 'Youth To The People' 'Yves Saint Laurent']

# %% [markdown]
# Pada kolom brand_name ditemukan adanya inkonsistensi dalam format kapitalisasi. Beberapa brand ditulis menggunakan huruf kapital seluruhnya, sementara sebagian lainnya menggunakan format huruf kapital di awal kata. Perbedaan ini termasuk dalam inkonsistensi format penulisan sehingga perlu dilakukan standarisasi agar data menjadi lebih seragam dan konsisten untuk keperluan analisis.

# %%
print(df['size'].unique())
# Out:
# [nan '3.4 oz/ 100 mL' '0.25 oz/ 7.5 mL' ... '0.25 oz/ 7.5 ml' '2.6 oz'
#  '.11 oz / 3.2 mL']

# %% [markdown]
# Kolom size menunjukkan adanya variasi format penulisan ukuran produk, seperti kombinasi satuan ounce (oz) dan mililiter (mL). Selain itu, terdapat nilai kosong (NaN) yang menandakan bahwa tidak semua produk memiliki informasi ukuran. Perbedaan format seperti “0.25 oz / 7.5 mL” dan “2 oz” selain itu ada juga penulisan "mL" dan "ml" menunjukkan bahwa data belum sepenuhnya distandarisasi, sehingga perlu normalisasi format satuan agar lebih konsisten untuk analisis.

# %%
print(df['variation_type'].unique())
# Out:
# [nan 'Size + Concentration + Formulation' 'Scent' 'Size' 'Color'
#  'Size + Concentration' 'Type' 'Formulation']

# %% [markdown]
# Kolom variation_type menunjukkan bahwa penulisan kategori sudah konsisten dalam penggunaan huruf kapital (Title Case) dan tanda pemisah “+”. Tidak ditemukan perbedaan format kapitalisasi sehingga dari sisi gaya penulisan dapat dikatakan seragam. Namun, terdapat perbedaan pada struktur variasinya, di mana sebagian produk hanya memiliki satu jenis variasi seperti “Size” atau “Color”, sedangkan sebagian lainnya menggabungkan beberapa atribut dalam satu field seperti “Size + Concentration” atau “Size + Concentration + Formulation”. Hal ini menunjukkan adanya ketidaksamaan kompleksitas variasi antar produk, meskipun secara penulisan sudah konsisten.

# %%
print(df['variation_value'].unique())
# Out:
# [nan '3.4 oz/ 100 mL' '0.25 oz/ 7.5 mL Eau de Parfum Spray' ...
#  '0.25 oz/ 7.5 ml' '2.6 oz' '2 oz / 60 mL eau de parfum spray']

# %% [markdown]
# Kolom variation_value berisi detail nilai dari variasi produk, seperti ukuran lengkap dengan keterangan “Eau de Parfum Spray”. Terlihat adanya variasi kapitalisasi seperti “Eau de Parfum Spray” dan “eau de parfum spray” yang menunjukkan inkonsistensi dalam penggunaan kapital pada format teks. Selain itu, beberapa nilai menggabungkan ukuran dan tipe produk sehingga berpotensi menyebabkan redundansi atau dobel data.

# %%
print(df['variation_desc'].unique())
# Out:
# [nan 'rosy-brown' 'for rich skin with yellow undertones'
#  'for rich to deep skin tones'
#  'clear with golden light-reflective minerals'
#  'for rich skin with red undertones' 'berry'
#  'for grey hair with cool/ash undertones' 'brick red (ultra-matte)'
#  'dusty mauve' 'cool desert sand' 'Bronzed, Summer, Tourmaline, Moonstone'
#  'colorless' 'taupe based brown' 'translucent/clear'
#  'highlight pale yellow'
#  'full-strip synthetic lashes with iconic glamour and voluminous drama'
#  'golden taupe' 'for blonde hair with warm/gold undertones'
#  'pinky brown with a matte finish'
#  'for light brown hair with warm/cool undertones'
#  'medium skin with a warm yellow undertone' 'cool taupe'
#  'nude taupe beige' 'light golden' 'light bright peach'
#  'medium to tan skin with peach undertones'
#  'pink based flesh tone/ iridescent beige'
#  'fair to light with warm pink undertones' 'contour caramel latte' 'black'
#  'for light/medium brown & silver hair' 'ivory' 'baby pink'
#  'golden copper' 'coconut-vanilla' 'icy white gold'
#  'For blonde hair with cool/ash undertones' 'clear' 'true black matte'
#  'For medium brown hair with cool/ash undertones'
#  'Rose Quartz pink with a satin finish (lipstick), Light rosy pink (Lip liner)'
#  'crystal-clear/translucent' 'glistening champagne with diamond reflects'
#  'medium brown' 'sheer creamy coconut' 'tan, peach' 'red'
#  'deep with a golden undertone' 'soft gold shimmer'
#  'FAIR WITH AN  OLIVE UNDERTONE' 'soft beige'
#  'tan to deep with an olive undertone' 'medium with a peach undertone'
#  'light to medium with a golden undertone' 'warm coral'
#  'fair with a peach undertone' 'luminous beige' 'iridescent gold-bronze'
#  'neutral beige' 'warm nude' 'clear pink' 'metallic rich chocolate'
#  'medium, golden undertone' 'for light neutral skin with peach undertones'
#  'completely sheer with luminous finish'
#  'for medium-tan warm skin with a golden hue'
#  'healthy/ sun-kissed glow - chestnut' 'warm pink' 'nude pink'
#  'medium nude pink with gold pearl'
#  'for very fair cool skin with pink undertones' 'for all skin tones'
#  'cool mid tone pink pink' 'matte rich brown' 'sunlit bronze'
#  'very light with cool undertones'
#  'fair skin tones with neutral undertones' 'soft baby pink with pearl'
#  'deep range' 'matte bronzer' 'warm deep brown' 'neutral medium brown'
#  'rose tinted lip & cheek stain' 'warm medium brown' 'cool light blonde'
#  'neutral blonde' 'golden pearl' 'baby-pink brightening'
#  'soft neutralrose' 'medium tan/ warm' 'medium cool' 'soft nude-pink'
#  'warm light brown' 'linen pink (matte end)/ soft gold (shimmer end)'
#  'neutral light brown' 'fair cool' 'medium warm' 'pitch black'
#  'true copper' 'jet black'
#  'light yellow peach corrects brown/grey/greenish discoloration under the eyes'
#  'a swirl of pearlescent white and pale peach'
#  'very light beige with a balance of pink and yellow undertones; for very light skin'
#  'light beige with yellow undertones; for light skin' 'a cool rosy beige'
#  'neutral pinky rose' 'muted pale blue' 'soft, warm pink glow' 'light tan'
#  'lush pink beige'
#  'light beige with neutral undertones; for fair to light skin'
#  'a soft pink shimmer'
#  'medium dark warm brown; sets and controls shine on dark to deep skin'
#  'light yellow peach' 'mid-tone mauve pink'
#  'golden light brown with olive and yellow undertones'
#  'light beige with yellow undertones; for fair to light skin'
#  'dark brown with red/yellow undertones; for deep skin'
#  'rich brown with a balance of yellow and red undertones for deepest skin (spf 30)'
#  'dark brown with yellow undertones'
#  'tanned beige with peachy yellow undertones; for medium to dark skin'
#  'pale pink' 'pearlescent champagne with pops of gold and copper pearl'
#  'a true light bronze' 'rich brown' 'a very light yellow' 'Natural'
#  'sultry mauve' 'blooming coral' 'warmed up nude peach'
#  'very deep with a neutral undertone' 'cool, rose champagne'
#  'Golden beige for light skin tones' 'very fair to fair'
#  'soft rose gold highlight' 'pink nude' 'warm berry pink'
#  'nude muted apricot' 'golden beige for medium skin tones'
#  'for medium skin with neutral undertones'
#  'bronze & gold eyeshadow palette' 'warm metallic gold'
#  'fairest with neutral undertones' 'medium golden bronze' 'soft rose'
#  'peachy nude' 'iconic nudey-pink' 'nude' 'papaya for deep skintones'
#  'Natural Soft Bronze' 'metallic champagne & matte black' 'matte pink'
#  'nude rosewood' 'incandescent ivory'
#  'neutral undertones for fair and light to medium blonde and red brows'
#  'deep rosy pink'
#  'warm undertones for dark blonde to light brown and red brows'
#  'ruby-red with a warm copper sparkle' 'smoky berry brown' 'yellow-toned'
#  'soft medium brown with a wash of sparkle'
#  'neutral undertones for light to medium blonde brows' 'berry rose'
#  'berry-rose' 'warm-russet'
#  'neutral undertones for dark blonde to medium brown and auburn brows'
#  'deep to very deep' 'white' '001M'
#  'fairest shade; with a cool neutral undertone' 'sheer plum brown'
#  'very fair, cool-neutral undertones' 'universal berry' 'blushing plum'
#  'deep, warm-neutral undertones' 'for lighter skintones' 'bright blue red'
#  'soft nude' 'very fair to moderately fair complexions'
#  'muted mauve matte' 'translucent'
#  'grapefruit pink with sunset yellow shift' 'berry blue + plum purple'
#  'very fair skin with pink undertones' 'natural pink'
#  'copper + rustic yellow' 'neutral rosey pink' 'transparent gloss'
#  'for medium tan – tan complexions' 'champagne gold for all skin types'
#  'tan skin with neutral undertones' 'deep to dark' 'warm peach'
#  'warm copper' 'Rosy mauve glow' 'Naked' 'full coverage soft lilac pink'
#  'a nude pink' 'mahogany' 'a delicate pink' 'pink'
#  'very fair skin with neutral undertones'
#  'medium to dark skin with neutral undertones'
#  'medium skin with warm undertones' 'the iconic Dior rosewood'
#  'orange red' 'a deep berry black' 'timeless black' 'brick red' 'coral'
#  'shade of denim blue and a gold hue' 'a radiant pink' 'iconic red matte'
#  'medium to deep' 'poison matte'
#  'Sheer pink balm to your perfect pink glow' 'warm bronze' 'matte black'
#  'light skintones' 'natural luminous black' 'pink rosewood'
#  'intense warm red' 'universal sheer' '1 mask'
#  'medium tan with warm, golden-olive undertones'
#  'light with cool, rosy-peach undertones' 'medium with neutral undertones'
#  'deep with neutral, subtle golden undertones'
#  'deepest with neutral, rich-brown undertones' 'true black'
#  'very light with cool pink undertones' 'magenta with iridescent pearl'
#  'medium deep with neutral undertones'
#  'translucent: for light to medium skin tones'
#  'deep with neutral undertones' 'all skin tones; translucent finish'
#  'bronze undertones' 'shimmering rose nude' 'olive'
#  'perfect universal red' 'contour, cool undertone for medium skin tones'
#  'soft copper sheen / supercharged copper shimmer'
#  'medium with warm golden undertones' 'pure platinum sparkle'
#  'soft mauve with shimmer' 'for tan skin w/ cool undertones'
#  'iced-out pearl' 'sheer rose nude' 'deep skin tones, neutral undertones'
#  'universal rose nude' 'for fair to medium skin tones'
#  'for very fair skin with warm yellow undertones' 'universal'
#  'sparkling copper' 'peachy pink' 'fair to light skin tones'
#  'for light to tan skin tones – great for brightening'
#  'cool for light medium to medium skin tones' 'sheer pink'
#  'for very fair skin with neutral undertones'
#  'metallic orchid/ metallic violet'
#  'warm tone for light skin / cinnamon bronze' 'black matte'
#  'true satin black' 'for medium to dark brown hair, warm undertone'
#  'glimmering rose gold' 'blue red'
#  'medium deep with warm golden undertones' 'white gold with gold shimmer'
#  'champagne glow for light medium-to-medium skin tones' 'iridescent pink'
#  'yellow for light medium to medium- skin tones' 'iridescent opal'
#  'for medium tan to dark bronze skin with olive to warm, yellow undertones'
#  'light-medium' 'dusty orange' 'violet/purple'
#  'a sheer juicy watermelon flavor' 'a rosy pink' 'for fair skintones'
#  'flushed pink neutral' 'transparent pink, custom to your PH'
#  'neutral beige infused with a powdery pink' 'coffee toned nude'
#  'soft neutral pink' 'tan to deep with neutral undertones'
#  'ultra fair with neutral undertones' 'sheer universal'
#  'tan with balanced, neutral undertones' 'intense black'
#  'targets dark circles and spots'
#  'short, round press-on nails with a french tip design and mini cherry accents'
#  'a natural short winged cat eye lash' 'highly pigmented black'
#  'a feathered short, cat-eye half lash'
#  'a mixed brown & black, natural short wispy lash' 'sheer purple tint'
#  'light cool pink' 'dusty rose' 'medium-dark brown' 'light to medium'
#  'transparent' 'subtle peach' 'deepest' 'true black mascara'
#  'pearlescent glowing shimmer' 'rich bronze with gold shimmer'
#  'rich black'
#  'light, neutral bronze with gold pearl for fair-light skin tones.'
#  'neutral taupe' 'trippy, acidic yellow' 'trippy, acidic yellow '
#  'high clear gloss' 'soft pink' 'the gucci red matte'
#  'vivid orange red sheer' 'light' 'the gucci red satin'
#  'warm rosewood colour with neutral tones and uplifting notes of pink and coral'
#  'warm undertones' 'soft matte pink lipstick color' 'pinky beige'
#  'dark brown' 'satin finish' 'light cool' 'Natural Beige'
#  'luminous coral pink' 'shades of pink, a plum and a brown'
#  'Very light skin with pink undertones' 'matte neutral' 'natural peach'
#  'beige peachy neutral' 'sparkling slivered champagne' 'rosy mauve'
#  'true red' 'sparkling rose gold' 'medium with warm soft rosy undertones'
#  'sheer cherry' 'light silver' 'sparkling cool pink' 'acid green'
#  'mint green' 'rose mauve' 'light medium to medium, warm rosy undertones'
#  'cool pink' 'neutral with balanced undertones'
#  'Neutral Undertone | Recommended For Medium Brown Hair'
#  'light, neutral undertones' 'neutral peach beige powder'
#  'a brick red combined with radiant light to recreate a vibrant fireside gleam'
#  'Medium, Yellow Undertones'
#  'a medium bronze shade fused with Luminous Light for a softer, candlelit warmth. (Ideal for light/medium complexions)'
#  'Bright Fuschia' 'champagne rose' 'light medium, neutral undertone'
#  'fairest with cool undertones' 'soft, warm pale yellow powder'
#  'clear with gold shimmer' 'light medium, cool undertone'
#  'a cool bronze shade fused with Diffused Light to mimic a ray of warm sunlight. (Ideal for light/medium complexions)'
#  'ultra black' 'light to medium cool brown' 'warm beige' 'Vivid Fuchsia'
#  'pewter' 'warm scarlet' 'brown' 'light medium to medium' 'desert rose'
#  'light to medium neutral blonde'
#  'A full volume, flared, v-formation criss-cross bold lash flattering to all eye shapes'
#  'fair to tan skin tones. neutral undertones for ultra-brightening.'
#  'a badass, bold burgundy (warm toned)' 'light volume, natural style '
#  'light, medium, and tan skin tones. golden undertones brighten and disguise under-eye darkness.'
#  'natural cool pink (cool toned)'
#  'extra rich skin tones with red undertones'
#  'warmer light-medium skin with neutral undertone' 'pinky nude'
#  'medium to tan with cool undertones' 'a trailblazing deep brown'
#  'warmer medium skin with golden undertone' 'medium nude mauve'
#  'warm red toned bronze suitable for medium tan to tan light skin tones'
#  'extreme black' 'fair skin tones with pink undertones'
#  'a warm dusty peach' 'golden-bronze shimmer for a true golden finish'
#  'light brown hair with warm undertones' 'universal blushed pink'
#  'neutral, soft pink rose' 'ultra-fair skin tones with pink undertones'
#  'eye opening effect' 'translucent blue'
#  'for neutral brown hair with mix of cool and warm undertones'
#  'translucent orange'
#  'golden toned bronze suitable for light medium to medium skin tones'
#  'peachy antique-rose based shimmer that adds a warm rosy glow'
#  'light pink' 'rose gold' 'neutral nude'
#  'perfect champagne glow to make any skin tone radiant and glossy'
#  'sheer pink, fresh watermelon scent' 'perfect champagne glow' 'caramel'
#  'cool-toned taupe brown' 'soft taupe' 'champagne, nude tone'
#  'subtle, sun-kissed effect' 'Medium with cool undertones'
#  'golden peach pearl' 'deep with golden olive undertones' 'cool rose pink'
#  'taupe brown' 'Light with warm undertones' 'burnt coral' 'bardot nude'
#  'sheer berry' 'light-medium tan'
#  'For extra light to light-medium skin tones' 'soft gold' 'sheer'
#  'subtle luscious lilac' 'natural gloss' 'gold' 'juicy pink'
#  'ultra violet colour flip' 'supersonic power pink'
#  'soft red with a subtle red sparkle center' 'mocha'
#  'for neutral undertones' 'soft beige shade with warm undertones'
#  'very deep Complexion with cool red undertones'
#  'golden brown shade with warm undertones' '(W) (Soft Beige)'
#  'fair complexion with neutral undertones' 'bright fuchsia'
#  'taupe shade with warm undertones' 'intense ultra black'
#  'light to medium with olive yellow undertone'
#  'for deep skintones with neutral/neutral red undertones'
#  'dark skin with golden undertones'
#  'matte warm dusty peach/ shimmering warm pale nude peach'
#  'tan skin with cool pink undertones' 'shimmering champagne pink'
#  'tinted cool soft pink' 'light skin with neutral yellow undertones'
#  'rich cocoa/ shimmering golden peach'
#  'uplift me: soft peach/amuse me: soft pink' 'translucent light pink'
#  'Coquille: Sheer Nude Shimmer / Parasol: Sheer Rose Shimmer'
#  'playful bubblegum pink' 'shimmering bronze' 'rosy pink' 'true jet black'
#  'sparkling white gold' 'neutral dusty rose with soft-luminous shimmer'
#  'nudy pink'
#  'transparent with banana brightening powders for medium to deep skin'
#  'Cool' 'medium with golden undertones' 'sheer golden medium'
#  'Medium with neutral cool undertones' 'soft warm pink'
#  'light with cool undertones' 'neutral bronze (formerly Globe)'
#  'light medium with golden undertones' 'creamy rosy beige'
#  '(notes\xa0of\xa0jasmine,\xa0sandalwood,\xa0vanilla)'
#  'pearly medium golden' 'medium bronze' 'cool blonde' 'leafy green'
#  'light-medium w/ neutral undertones' 'satin black'
#  'Near-white for mixing & artistry looks' 'chestnut rose'
#  'for medium to dark blonde hair' 'ultra-black' 'plum brown'
#  'rich deep truffle' 'soft petal pink'
#  'for fair skin with cool pink undertones'
#  'medium sand with warm undertone' 'light brown with neutral undertones'
#  'for medium skin with cool undertones' 'rich deep coffee'
#  'iconic chestnut rose (formerly Lolita)'
#  'For light to medium skin with neutral undertones'
#  'medium to deep skin, neutral undertone' 'pink brown'
#  'sheer magenta with silver sparkle' 'cool vintage rose'
#  'Medium with neutral peach undertones'
#  'medium-deep skin with neutral undertone' 'cool dusty rose'
#  'perfect for very fair to medium skintones' 'pink gold shimmer'
#  'medium skin tones with olive, warm and golden undertones' 'light warm'
#  'very fair with neutral undertones' 'golden nude'
#  'warm coral luminescent pink' 'fair to medium skin tones'
#  'light with neutral undertones' 'very fair to medium skin tones'
#  'very fair with cool undertones' 'medium neutral'
#  'for fair to light skin tones' 'light coral pink' 'metallic pink rose'
#  'medium pink beige' 'fair' 'light pinky nude'
#  'medium beige with yellow undertones' 'olive with cool undertones'
#  'light with warm undertones' 'classic red' 'deep black'
#  'bronzed rose - for medium-deep to deep skin tones\u200b'
#  'warm mid tone nude' 'shimmer pale nude' 'bronzy copper'
#  'very deep neutral' 'light medium bronze' 'soft orchid' 'sheer vanilla'
#  'clear translucent pink' 'neutral pink with a plummy base'
#  'neutral baby-pink' 'light with golden-olive undertones'
#  'flexible light/medium' 'light/medium neutral blonde'
#  'perfect nude/ berry wine' 'berry wine' 'champagne shimmer'
#  '0.08 oz/ 2.5 ml' 'dark with warm undertones'
#  'medium-dark w/ neutral to warm undertones'
#  'round lash style, complimentary to all eye shapes'
#  'round lash style; gentle curl adds noticeable length, definition and soft volume'
#  'wispy, evenly dispersed light volume and length'
#  'Round lash, complementary to all eye shapes'
#  'a rounded, ultra wispy, layered lash'
#  'a round lash, complementary to all eye shapes'
#  'round lash, complementary to all eye shapes' 'baked coral'
#  'cocoa - dark brown skin with golden undertones' 'tan'
#  'porcelain very fair skin with golden undertones'
#  'tan - for tan skin tones' 'Warm Mauve' 'champagne' 'Terracotta Mauve'
#  'taupe platinum glitter'
#  'for fair to light skin tones with yellow undertones'
#  'for light skin with golden undertones'
#  'For fair skin with pink undertones' 'praline blush'
#  'for lighter medium skin with slightly golden undertones'
#  'for lighter tan skin with slightly yellow undertones'
#  'for lighter tan skin with neutral undertones' 'bright red' 'bronze'
#  'for light to medium skin tones'
#  'Sand - for medium skin neutral-yellow undertones' 'Translucent'
#  'for fair skin tones with rosy undertones'
#  'medium skin tones with yellow undertones' 'yellow gold'
#  'medium to tan skin tones with olive and golden undertones'
#  'fair to light skin with redness' 'crimson red'
#  'tan to deep skin with dullness & uneven tone'
#  'for oily, normal, combination skin' 'brown baby pink' 'golden champagne'
#  'for dry, normal, combination skin'
#  'light to medium blonde hair with neutral undertones' 'sheer pale pink'
#  'natural matte finish for light-medium to medium skin tones (warm golden)'
#  'fair with cool undertones' 'muted rose pink'
#  'warms light to light medium skin tones' 'deep plum' 'soft muted peach'
#  'soft matte finish for light-medium to medium skin tones (warm golden)'
#  'sparkling golden yellow' 'warms fair to light skin tones' 'burnt nude'
#  'luminous soft gold that flatters medium skin tones'
#  'bright coral with gold pearl' 'true brown'
#  'peach base with a gold pearl' 'rich plum' 'mauve bronze & pink beige'
#  'golden sand' 'deep charcoal with galaxy glitter' 'soft champagne'
#  'light peach' 'Clear' 'Universal Brown' 'for red hair' 'neutral brown'
#  'warm crème' 'deep with cool undertones' 'warm neutral' 'deep skin'
#  'dusty rose shimmer' 'deep bronze' 'blackest black' 'golden peach'
#  'medium dark brown' 'white gold with pink pearl'
#  'medium with warm olive undertones' 'medium to medium tan'
#  'very deep bronze' 'luminous bronze' 'medium tan with neutral undertones'
#  'Amber, magnolia, woods' 'Amber, Magnolia, Woods' 'lilac purple'
#  'candy pink' 'L2.3 - Light with neutral undertones'
#  'shimmering deep coral with gold pearl'
#  'M1.75 - Medium with neutral undertones'
#  'L1 - Very light with neutral undertones'
#  'M1 - medium with warm undertones, and a golden tone'
#  'M4 - medium to medium-deep with warm undertones, and a golden tone'
#  'soft rose nude' 'sheer peachy pink with golden shimmer'
#  'peachy pink w/ golden shimmer' 'dusty rose - sheer'
#  'diffused brown with golden sheen'
#  'MD4 - Medium-deep to deep with warm undertones, and an olive tone'
#  'very light to light' 'light/medium bronze with neutral undertones'
#  'peachy pink with golden shimmer' 'vivid siren red'
#  'peachy-pink shimmer/  sheer light brown shimmer' 'shimmering deep coral'
#  'peachy-pink shimmer/ sheer light brown shimmer'
#  'shimmering bronze with gold shimmer'
#  'sheer peachy pink with golden shimmer/shimmering mauve' 'warm brown'
#  'red to color correct deep to very deep skin tones'
#  'light with cool tone' 'chocolate brown' 'black satin'
#  'dark with warm undertone' 'pink coral' 'neutral undertone' 'mauvy pink'
#  'neutral warm' 'light neutral pink' 'pretty pop of orange coral - blush'
#  'soft peach' 'cool toned rose tan with matte finish' 'light-medium nude'
#  'Bronze + Hilite: golden sun-kiss' "brown circa 60's with matte finish"
#  'warm-toned coral nude' 'fair nude - glossy finish'
#  'bronzed nude- bronzer' 'warm caramel coral' 'fair neutral nude'
#  'medium to dark' 'cool toned rosy pink with matte finish'
#  "medium to tan, golden undertones (Patrick's Shade)"
#  'for fair to medium dark skin' 'very fair, neutral undertones'
#  'light, neutral rosy undertones' 'champagne nude with silver reflects'
#  'pearlescent & matte medium pink' 'soft matte mauve'
#  'larger-than-life volume with alternating lengths'
#  'neutral cool undertones, for light to medium brown hair' 'DEEP NEUTRA'
#  'soft pink peach nude' 'warm rose with golden pearl'
#  'medium deep with red neutral undertones' 'terracotta demi-matte'
#  'romantic nude pink' 'glittering iridescent'
#  'glitter bronzed terracotta nude with rose gold sparkle'
#  'the ultimate black' 'shimmering copper' 'soft plum rose'
#  'golden bronze with copper pearls'
#  'metallic rose with golden peach iridescence' 'mid-tone brick red'
#  'medium with warm undertone' 'Multi' 'golden warm' 'pink pearl'
#  'pink neutral' 'rose beige' 'vibrant pink' 'intensely black' 'true mauve'
#  "rose bronze (Selena's go-to shade)" 'true tan with neutral undertones'
#  'medium\xa0tan\xa0with warm olive undertones'
#  'deep with warm golden undertones' 'true gold' 'deep dusty plum'
#  'peach undertones to brighten medium tan complexions' 'nude mauve'
#  'warm honey for medium-to-medium deep complexions' 'warm neutral beige'
#  'for light to medium brown hair' 'light, neutral pink'
#  'a warm mix of red and soft purple undertones'
#  'subtle golden undertones with a glass-like glow finish'
#  'medium, warm pink' 'light bronze with a cool undertone'
#  'universal and suitable for all skin tones.' 'light medium'
#  'black with a cool undertone'
#  'with its yellow base, this shade is great for light-medium skin tones '
#  'ultra sheer, light-reflective luminizer with a translucent satin-pearl finish'
#  'an innocent pink' 'elegant pink with a hint of shimmer'
#  'a golden coral with a hint of peach' 'a deep mahogany chocolate'
#  'rich ebony' 'mauve' 'fair skin tone /cool pink undertone'
#  'very deep skin tone, neutral undertone' 'cool blush' 'deep berry'
#  'very deep skin tone / red' 'rosy bronze' 'rich red copper / copper gold'
#  'beige pink' 'a cool-toned mauve'
#  'for very light skintones with peach undertones' 'universal champagne'
#  'a neutral shade for medium to tan skin tones'
#  'for medium skin tones with golden beige undertones'
#  'for fair to light medium skin tones' 'rosy nude'
#  'light to medium skin tones with neutral undertones' 'Universal nude'
#  'matte classic red' 'matte mauve pink' 'classic black'
#  'nourishing & moisturzing' 'matte true blue red' 'high shine classic red'
#  'for tan to deep skin with golden yellow undertones'
#  'pink nude with gold pearls' 'for deep skin with neutral undertones'
#  'old rose' 'for light skin with neutral undertones'
#  'clear w/ blue-violet duochrome pearls' 'medium with Neutral undertone'
#  'Crème' 'muted coral nude'
#  'full volume, wispy with added thickness at outer corners' 'red orange'
#  '(Peach)' 'deep tan with red/yellow undertone' '(Taupe) sheer'
#  'fair with neutral undertones'
#  'for light-medium skin with neutral undertones'
#  'Peach tone that gives the effect of glowing, morning light' 'dramatic'
#  'light with neutral undertone' 'universal shade' 'Raisin'
#  'clear with iridescent pearl' 'medium pink' 'pink gold' 'peachy coral'
#  'very deep with red undertones'
#  'A lengthening lash with wispy curled fibers for a soft natural look.'
#  'nourishing and soothing' 'sheer bright pink' 'berry, rose gold & copper'
#  'flare lash style, most complimentary to hooded, almond & downturned eye shapes'
#  'Full Volume' 'light cool brown'
#  'opalescent gold sheen / platinum shimmer' 'Mauve Pink'
#  'light-medium w/ neutral undertone'
#  'matte light mocha base shade, matte medium dark taupe, matte plum, matte deep raisin, silver/lilac duochrome, emerald shimmer, metallic eggplant'
#  'Pore Minimizer' 'universal bronze shimmer' 'shimmering lilac' 'Black'
#  'balanced with a slight olive tone for medium-tan skin. neutral undertone.'
#  'balanced tone for light skin. neutral undertone.'
#  'balanced tone for fairest skin' 'lacquer red' 'sheer cocoa'
#  'balanced with a slight golden tone for fair skin, neutral undertone'
#  '4 upper, 4 lower' '6 pack' 'warm rust' 'medium with cool undertone'
#  'skin tone: medium, undertone: cool'
#  'Light-medium with a neutral undertone'
#  'subtle, natural contour with medium shades' 'True Red'
#  'a soft gold with pinky-peach pearl - recommended for all skintones'
#  'medium taupe brown' 'Dark to deep with a neutral undertone' 'cranberry'
#  'champagne, silver & copper' 'shimmering rosey taupe'
#  'champagne with kaleidoscope pearl' 'Fair with Neutral Peach Undertones'
#  'light peachy pink' 'medium skin with peach undertones'
#  'very deep skin with a balance of warm & cool undertones'
#  'medium skin with neutral undertones' 'metallic bronze champagne'
#  'cool mauve' 'for ivory/fair complexions with beige undertones'
#  'gold bronze' 'multi-length fibers dramatically volumize lashes'
#  'tan skin with warm, golden undertones'
#  'light to medium skin with a balance of warm & cool undertones'
#  'highly pearled light yellow gold'
#  'light to medium complexions with beige undertones' 'champagne glow'
#  'matte rosy pink' 'medium skin with a balance of warm & cool undertones'
#  'tan skin with yellow undertones'
#  'deeper skin with warm, golden undertones'
#  'deep skin with a balance of warm & cool undertones'
#  'fair skin with neutral undertones' 'light, medium brown & caramel hair'
#  'light, medium & ash brown hair'
#  'fair skin with a balance of warm & cool undertones'
#  'tan skin with warm, peach undertones' 'dark blonde & red hair'
#  'medium & dark brown hair'
#  'fair to light skin with cool, pink or rosy undertones' 'blood orange'
#  'warm toned, medium peach' 'red orange matte' 'nude with gold pearl'
#  'medium, neutral undertone' 'light-medium, warm peachy undertone'
#  'translucent pink with gold shimmer' 'midtone neutral'
#  'neutral peach with shimmer/pinky peach' 'warm red'
#  'soft nude, frosted beige, silver sparkle and charcoal'
#  'medium dark coral' 'Shimmering pinks, cool purple and dirty red'
#  'rich tan with golden undertones' 'matte true red' 'Vivid Rich Gold'
#  'soft mauve pink' 'satin peach pink' 'soft baby pink'
#  'radiant duo-tone bronzer' 'fair with rosy undertones'
#  'tan with golden undertones' 'deepest with rosy undertones'
#  'tan with neutral undertones' 'hot pink' 'muted warm red' 'rich blue red'
#  'light pink nude' 'translucent kiss of pink' 'spiced terracotta red'
#  'light golden bronze' 'rosey pink' 'medium brown with neutral undertones'
#  'Fairest with neutral to rosy undertones' 'semi-sheer, milky nude pink'
#  'sun-kissed rosy nude' 'light bronze' 'juicy sheer nude'
#  'bright berry fuchsia' 'matte blackest black' 'cool beige satin'
#  'sheer nude' 'silver holographic'
#  'light champagne gold with silver sparkle' 'deep red'
#  'medium with subtle pink undertone' 'medium cool with an olive undertone'
#  'medium dark warm' 'dark neutral with a golden undertone'
#  'reddish-brown metallic' 'light neutral' 'rich black satin'
#  'metallic blue' 'ultra deep warm with a peachy undertone'
#  'universal taupe' 'fair cool with a rosy undertone'
#  'cool rosebud pink with light reflecting pearls'
#  'black liquid liner and black gel pencil' 'gold reflections'
#  'ideal for medium-to-deep complexions with warm undertones'
#  'subtly flared for everyday wear' 'naturally flared & crisscrossed'
#  'natural volume, round lash style, most complimentary to almond, monolid, and hooded eye shapes, vegan mink material '
#  'full volume, flared lash style, complementary to all eye shapes, premium vegan fibres'
#  'for light to golden blonde hair, neutral undertone'
#  'high volume, dramatic style'
#  'natural volume, flared lash style, complementary to all eye shapes, hemp-derived fibres'
#  'soft nude rose' 'tan with warm olive undertones' 'poppy pink'
#  'cool beige coffee' 'medium tan, golden undertone' 'just bitten'
#  'medium warm, peach undertone' 'glassy bronze gold' 'glassy oyster pearl'
#  'works on most complexions' 'soft warm rose'
#  'chocolate/rich chocolate, tabac/warm bronze, neige/iridescent ivory'
#  'warm rose, peony, café crème, mulled wine' 'rich Chocolate'
#  'for black/brown & black hair (charcoal black)' 'rose bright pink'
#  'medium, peach undertone' 'blood red' 'deep shade with warm undertones 7'
#  'brightens and evens skintone' 'amber nude shimmer'
#  'light. peach undertone' 'beige nude' 'deep chocolate nude'
#  'deep rich brown' 'deep. red undertone' 'deep crimson' 'cherry red']

# %% [markdown]
# Kolom variation_desc terlihat memiliki isi yang sangat beragam dan tidak seragam. Dari data yang muncul, ada yang hanya berupa nama warna seperti berry, cool taupe, atau black, tetapi ada juga yang berupa penjelasan panjang seperti untuk jenis kulit tertentu (for rich skin with yellow undertones, fair to light with warm pink undertones) bahkan sampai deskripsi produk seperti bulu mata sintetis dengan efek dramatis. Artinya, kolom ini tidak hanya menyimpan satu jenis informasi saja, melainkan campuran antara warna, target pengguna, undertone, dan deskripsi produk.
#
#
# Kondisi ini menunjukkan adanya inkonsistensi struktur data karena satu kolom menampung beberapa tipe informasi sekaligus. Jika dibiarkan, hal ini bisa menyulitkan analisis lanjutan, misalnya saat ingin mengelompokkan produk berdasarkan warna saja atau berdasarkan jenis kulit saja. Idealnya, informasi seperti ini dipisahkan agar lebih terstruktur dan mudah dianalisis.

# %%
print(df['ingredients'].unique())
# Out:
# ["['Capri Eau de Parfum:', 'Alcohol Denat. (SD Alcohol 39C), Parfum (Fragrance) D-Limonene, Linalool, Benzyl Salicylate, Ethylhexyl Methoxycinnamate, Butyl Methoxydibenzoylmethane, Ethylhexyl Salicylate, Benzl Benzoate, Citral, Geraniol, Eugenol, Benzyl Alcohol, Farnesol, Citronellol, Isoeugenol.', 'Invisible Post Eau de Parfum:', 'Alcohol Denat. (SD Alcohol 39C), Parfum (Fragrance) Ethylhexyl Methoxycinnamate, Ethylhexyl Salicylate, Butyl Methoxydibenzoylmethane, Benzyl Benzoate, Citral, Coumarin, Limonene, Alpha-Isomethyl Ionone, Linalool.', 'Kashbah Eau de Parfum:', 'Alcohol Denat. (SD Alcohol 39C), Parfum (Fragrance) Coumarin, Ethylhexyl Methoxycinnamate, Butyl Methoxydibenzoylmethane, Ethylhexyl Salicylate, D-Limonene, Eugenol, Linalool, Citronellol, Geraniol, Cinnamal, Citral.', 'L’Air Barbes Eau de Parfum:', 'Alcohol Denat. (SD Alcohol 39C), Parfum (Fragrance) Benzyl Salicylate, D-Limonene, Ethylhexyl Methoxycinnamate, Butyl Methoxydibenzoylmethane, Ethylhexyl Salicylate, Linalool Citral, Alphaisomethyl Ionone, Benzyl Benzoate, Geraniol Farnesol, Isoeugenol, Eugenol.', 'La Habana Eau de Parfum:', 'Alcohol Denat. (SD Alcohol 39C), Parfum (Fragrance) Ethylhexyl Methoxycinnamate, Ethylhexyl Salicylate, Butyl Methoxydibenzoylmethane, Benzyl Alcohol, Benzyl Benzoate, Benzyl Cinnamate, Cinnamal, Citral, Coumarin Limonene, Eugenol, Alpha-Isomethyl Ionone, Linalool.', 'Purple Haze Eau de Parfum:', 'Alcohol Denat. (SD Alcohol 39C), Parfum (Fragrance) Octoxynol-10, D-Limonene, Ethylhexyl Methoxycinnamate, Butyl Methoxydibenzoylmethane, Ethylhexyl Salicylate, Geraniol, Linalool, Coumarin, Farnesol, Eugenol, Citral.', 'Rainbow Bar Eau de Parfum:', 'Alcohol Denat. (SD Alcohol 39C), Parfum (Fragrance) D-Limonene, Ethylhexyl Methoxycinnamate, Butyl Methoxydibenzoylmethane, Ethylhexyl Salicylate, Hexyl Cinnamal, Citronellol, Linalool, Coumarin, Eugenol, Citral, Isoeugenol, Geraniol.']"
#  "['Alcohol Denat. (SD Alcohol 39C), Parfum (Fragrance) Ethylhexyl Methoxycinnamate, Ethylhexyl Salicylate, Butyl Methoxydibenzoylmethane, Benzyl Alcohol, Benzyl Benzoate, Benzyl Cinnamate, Cinnamal, Citral, Coumarin Limonene, Eugenol, Alpha-Isomethyl Ionone, Linalool.']"
#  "['Alcohol Denat. (SD Alcohol 39C), Parfum (Fragrance) D-Limonene, Ethylhexyl Methoxycinnamate, Butyl Methoxydibenzoylmethane, Ethylhexyl Salicylate, Hexyl Cinnamal Citronellol, Linalool, Coumarin, Eugenol, Citral, Isoeugenol, Geraniol.']"
#  ...
#  "['Alcohol, Aqua / Water / Eau, Parfum / Fragrance, Limonene, Linalool, Coumarin, Butyl Methoxydibenzoylmethane, Alpha-Isomethyl Ionone, Geraniol, Citral, Citronellol, Tris(Tetramethylhydroxypiperidinol) Citrate, Ci 15985 / Yellow 6, Cinnamal, Ci 14700 / Red 4, Isoeugenol, Eugenol, Ci 19140 / Yellow 5, Ci 42090 / Blue 1.']"
#  "['Alcohol, Parfum/Fragrance, Aqua/Water, Limonene, Linalool, Butyl Methoxydibenzoylmethane, Citral, Citronellol, Alpha-Isomethyl Ionone, Geraniol, Coumarin, Ci 60730/Ext. Violet 2, Ci 15985/Yellow 6, Ci 42090/Blue 1.']"
#  "['Diisostearyl Malate, Bis-Behenyl/Isostearyl/Phytosteryl Dimer Dilinoleyl Dimer Dilinoleate, Pentaerythrityl Adipate/Caprate/Caprylate/Heptanoate, Vp/Hexadecene Copolymer, Paraffin, Octyldodecanol, Cera Microcristallina/Microcrystalline Wax/Cire Microcristalline, Sorbitan Sesquioleate, Synthetic Wax, Disteardimonium Hectorite, Tocopheryl Acetate, Ethylene/Propylene Copolymer, Ci 77891/Titanium Dioxide, Propylene Carbonate, Parfum/Fragrance, Mentha Piperita Oil/Peppermint Oil, Dextrin Palmitate, Tocopherol, Ci 45410/Red 28 Lake, Alumina, Ci 19140/Yellow 5 Lake, Limonene, Mangifera Indica Seed Oil/Mango Seed Oil, Sodium Hyaluronate, Hydrogenated Polyisobutene, Caprylic/Capric Triglyceride, Aqua/Water/Eau, 1,2-Hexanediol, Mangifera Indica Fruit Extract/Mango Fruit Extract, Punica Granatum Fruit Extract, Anemarrhena Asphodeloides Root Extract.']"]

# %% [markdown]
# Kolom ingredients memiliki isi yang beragam dan tidak seragam. Sebagian data hanya berupa daftar bahan yang dipisahkan dengan koma, tetapi ada juga yang memuat beberapa varian produk dalam satu baris serta penggunaan tanda baca yang berbeda-beda.
#
# Hal ini menunjukkan bahwa kolom tersebut tidak memiliki struktur yang konsisten dan mencampur beberapa format penulisan sekaligus. Akibatnya, informasi yang tersimpan di dalamnya menjadi kurang terstruktur dan tidak sepenuhnya seragam antar baris data.

# %%
print(df['highlights'].unique())
# Out:
# ["['Unisex/ Genderless Scent', 'Warm &Spicy Scent', 'Woody & Earthy Scent', 'Fresh Scent']"
#  "['Unisex/ Genderless Scent', 'Layerable Scent', 'Warm &Spicy Scent']"
#  "['Unisex/ Genderless Scent', 'Layerable Scent', 'Woody & Earthy Scent']"
#  ...
#  "['Best for Oily, Combo, Normal Skin', 'Without Parabens', 'Without Mineral Oil', 'Matte Finish', 'Salicylic Acid']"
#  "['Natural Finish', 'Without Mineral Oil', 'Without Parabens']"
#  "['Hyaluronic Acid', 'High Shine Finish', 'Plumping', 'Hydrating', 'Medium Coverage']"]

# %% [markdown]
# Kolom highlights berisi daftar keunggulan produk dalam bentuk list, seperti jenis scent (Fresh, Woody), klaim bahan (Hyaluronic Acid, Salicylic Acid), hingga klaim manfaat (Hydrating, Matte Finish, Medium Coverage).
#
# Isinya sangat beragam karena mencampur kategori parfum, skincare, dan makeup dalam satu kolom. Ini menunjukkan bahwa highlights menampung berbagai jenis informasi tergantung tipe produknya, sehingga variasinya cukup tinggi antar baris data.

# %%
print(df['primary_category'].unique())
# Out:
# ['Fragrance' 'Bath & Body' 'Mini Size' 'Hair' 'Makeup' 'Skincare'
#  'Tools & Brushes' 'Men' 'Gifts']

# %% [markdown]
# Kolom ini sudah ringkas dan cocok. Namun, terdapat pencampuran antara jenis produk (misalnya Skincare, Makeup) dan kategori administratif (seperti Mini Size, Gifts), yang berpotensi membingungkan saat analisis dan pengelompokan data.

# %%
print(df['secondary_category'].unique())
# Out:
# ['Value & Gift Sets' 'Women' 'Body Moisturizers' 'Fragrance' 'Men'
#  'Candles & Home Scents' 'Body Care' 'Hair Styling & Treatments'
#  'Shampoo & Conditioner' 'Mini Size' 'Lip' 'Moisturizers' 'Treatments'
#  'Eye Care' 'Lip Balms & Treatments' 'Sunscreen' 'Cleansers' 'Masks'
#  'Skincare' 'Face' 'Eye' 'Cheek' 'Hair' 'Tools' 'Brushes & Applicators'
#  'Makeup Palettes' 'Beauty Tools' 'Accessories' 'Makeup' 'Bath & Shower'
#  'Wellness' 'High Tech Tools' 'Shop by Concern' nan 'Self Tanners'
#  'Shaving' 'Hair Tools' 'Nail' 'Beauty Accessories' 'Beauty Supplements'
#  'Other Needs' 'Bath & Body']

# %% [markdown]
# Kolom ini menunjukkan pencampuran berbagai dimensi data dalam satu level, mencakup jenis produk (Body Care), segmentasi (Men, Women), hingga kategori administratif (Value & Gift Sets). Kehadiran nilai nan serta tumpang tindih kategori (seperti munculnya kembali kategori Fragrance dan Skincare) mengindikasikan struktur taksonomi yang belum konsisten. Diperlukan standarisasi hierarki untuk menghindari bias pengelompokan dan memastikan akurasi pada tahap analisis data.

# %%
print(df['tertiary_category'].unique())
# Out:
# ['Perfume Gift Sets' 'Perfume' 'Rollerballs & Travel Size'
#  'Body Lotions & Body Oils' nan 'Cologne' 'Diffusers'
#  'Deodorant & Antiperspirant' 'Candles' 'Hair Masks'
#  'Leave-In Conditioner' 'Shampoo' 'Hair Oil' 'Hair Styling Products'
#  'Scalp Treatments' 'Conditioner' 'Lip Balm & Treatment' 'Moisturizers'
#  'Face Serums' 'Eye Creams & Treatments' 'Face Sunscreen'
#  'Face Wash & Cleansers' 'Face Oils' 'Toners' 'Face Masks' 'Facial Peels'
#  'Hand Cream & Foot Cream' 'Decollete & Neck Creams' 'Exfoliators'
#  'Hair Spray' 'Hair Primers' 'Tinted Moisturizer' 'Mascara'
#  'Setting Spray & Powder' 'Highlighter' 'Concealer' 'Eyebrow' 'Blush'
#  'Face Sets' 'Dry Shampoo' 'Curling Irons' 'Brushes & Combs'
#  'Hair Straighteners & Flat Irons' 'Hair Dryers' 'Eyeshadow' 'Lipstick'
#  'Eye Palettes' 'Contour' 'Lip Gloss' 'Eye Brushes' 'Foundation'
#  'False Eyelashes' 'Cheek Palettes' 'Lip Liner' 'Bronzer' 'Face Brushes'
#  'Tweezers & Eyebrow Tools' 'Eye Sets' 'Eye Primer' 'Eyeliner'
#  'Sharpeners' 'Accessories' 'Liquid Lipstick' 'Face Primer' 'Lip Sets'
#  'Body Wash & Shower Gel' 'BB & CC Cream' 'Eye Masks' 'Facial Rollers'
#  'Anti-Aging' 'Face Wipes' 'Blemish & Acne Treatments'
#  'Sponges & Applicators' 'Brush Cleaners' 'Makeup Removers' 'Brush Sets'
#  'Night Creams' 'Mists & Essences' 'Scrub & Exfoliants' 'Color Correct'
#  'Damaged Hair' 'Hair Thinning & Hair Loss' 'Color Care'
#  'Cologne Gift Sets' 'Lip Plumper' 'Beauty Supplements'
#  'Body Mist & Hair Mist' 'Cellulite & Stretch Marks' 'Body Sunscreen'
#  'Sheet Masks' 'For Body' 'For Face' 'Face Wash'
#  'Moisturizer & Treatments' 'Eye Cream' 'Skincare Sets' 'Aftershave'
#  'Facial Cleansing Brushes' 'Shaving' 'Hair Dye & Root Touch-Ups'
#  'Hair Supplements' 'Intimate Care' 'Hair Removal' 'Lip Stain'
#  'Eyelash Curlers' 'Makeup Bags & Travel Cases' 'Blotting Papers'
#  'BB & CC Creams' 'Under-Eye Concealer' 'Makeup & Travel Cases'
#  'Holistic Wellness' 'Teeth Whitening' 'Bath Soaks & Bubble Bath'
#  'Sunscreen' 'Body Products' 'Shampoo & Conditioner'
#  'Hand Sanitizer & Hand Soap' 'Lip Brushes' 'Manicure & Pedicure Tools']

# %% [markdown]
# Pada kolom ini isi data sudah lebih spesifik dan berfokus pada tipe produk yang jelas (misalnya Shampoo, Serum, Mascara, Face Masks), sehingga cocok untuk analisis yang lebih detail. Namun, masih terdapat nilai nan serta potensi overlap dengan secondary category (seperti Moisturizers atau Lip Balm & Treatments), yang menunjukkan struktur belum sepenuhnya bersih dan perlu penyelarasan agar tidak terjadi duplikasi level kategori saat analisis.

# %% [markdown]
# ### **Missing Values**

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#                     Null Ratio in %
# product_id                 0.000000
# product_name               0.000000
# brand_id                   0.000000
# brand_name                 0.000000
# loves_count                0.000000
# rating                     3.272899
# reviews                    3.272899
# size                      19.201789
# variation_type            17.000235
# variation_value           18.813280
# variation_desc            85.283730
# ingredients               11.125500
# price_usd                  0.000000
# value_price_usd           94.690370
# sale_price_usd            96.821286
# limited_edition            0.000000
# new                        0.000000
# online_only                0.000000
# out_of_stock               0.000000
# sephora_exclusive          0.000000
# highlights                25.983047
# primary_category           0.000000
# secondary_category         0.094184
# tertiary_category         11.655286
# child_count                0.000000
# child_max_price           67.577113
# child_min_price           67.577113

# %% [markdown]
# Pada tahap ini, kita akan melihat seberapa banyak data yang hilang pada seluruh kolom. Dan terlihat bahwa kolom:
#
# - rating
# memiliki missing values sekitar 3%, yang dimana ini cukup kecil indikasi hilangnya data pada kolom tersebut. Sehingga perlu ditangani sesuai kebutuhan analisis.
#
# - reviews
# memiliki missing values sekitar 3%, yang dimana ini cukup kecil indikasi hilangnya data pada kolom tersebut. Sehingga perlu ditangani sesuai kebutuhan analisis.
#
# - size
# memiliki missing values sekitar 19%, yang dimana ini cukup besar indikasi hilangnya data pada kolom tersebut. Sehingga perlu ditangani atau dihapus.
#
# - variation_type
# memiliki missing values sekitar 17%, yang dimana ini cukup besar indikasi hilangnya data pada kolom tersebut. Sehingga perlu ditangani atau dihapus.
#
# - variation_value
# memiliki missing values sekitar 18%, yang dimana ini cukup besar indikasi hilangnya data pada kolom tersebut. Sehingga perlu ditangani atau dihapus.
#
# - variation_desc
# memiliki missing values sekitar 85%, yang dimana ini cukup besar indikasi hilangnya data pada kolom tersebut. Sehingga perlu ditangani atau dihapus.
#
# - ingredients
# memiliki missing values sekitar 11%, yang dimana ini cukup besar indikasi hilangnya data pada kolom tersebut. Sehingga perlu ditangani atau dihapus.
#
# - value_price_usd
# memiliki missing values sekitar 94%, yang dimana ini cukup besar indikasi hilangnya data pada kolom tersebut. Sehingga perlu ditangani atau dihapus.
#
# - sale_price_usd
# memiliki missing values sekitar 96%, yang dimana ini cukup besar indikasi hilangnya data pada kolom tersebut. Sehingga perlu ditangani atau dihapus.
#
# - highlights
# memiliki missing values sekitar 26%, yang dimana ini cukup besar indikasi hilangnya data pada kolom tersebut. Sehingga perlu ditangani atau dihapus.
#
# - secondary_category
# memiliki missing values sekitar 0.09%, yang dimana ini sangat kecil namun perlu tetap di tangani atau di hapus.
#
# - tertiary_category
# memiliki missing values sekitar 11%, yang dimana ini cukup besar indikasi hilangnya data pada kolom tersebut. Sehingga perlu ditangani atau dihapus.
#
# - child_max_price
# memiliki missing values sekitar 67%, yang dimana ini cukup besar indikasi hilangnya data pada kolom tersebut. Sehingga perlu ditangani atau dihapus.
#
# - child_min_price
# memiliki missing values sekitar 67%, yang dimana ini cukup besar indikasi hilangnya data pada kolom tersebut. Sehingga perlu ditangani atau dihapus.

# %% [markdown]
# ### **Duplicated Values**

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, brand_id, brand_name, loves_count, rating, reviews, size, variation_type, variation_value, variation_desc, ingredients, price_usd, value_price_usd, sale_price_usd, limited_edition, new, online_only, out_of_stock, sephora_exclusive, highlights, primary_category, secondary_category, tertiary_category, child_count, child_max_price, child_min_price]
# Index: []
#
# [0 rows x 27 columns]

# %% [markdown]
# Tidak ditemukan duplicate value pada dataset, sehingga dapat disimpulkan bahwa data sudah bersih dari duplikasi dan tidak memerlukan proses penghapusan data.

# %% [markdown]
# ### **Outliers Values**

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom              Persentase Outliers
# brand_id                     16.788321
# loves_count                  11.196138
# rating                        3.991053
# reviews                      10.748764
# price_usd                     9.948199
# value_price_usd               0.329644
# sale_price_usd                0.129503
# limited_edition               7.028491
# new                           7.169767
# online_only                  21.909583
# out_of_stock                  7.369908
# sephora_exclusive             0.000000
# child_count                  12.962091
# child_max_price               3.790911
# child_min_price               3.802684

# %% [markdown]
# Pada tahap ini, kita akan melihat nilai ekstrem (outliers) pada kolom yang bertipe data kan numerik. Hal ini dilakukan agar mendapatkan insight yang akurat sehingga dapat memperkuat analisis dan model yang akan kita bangun nantinya.
#
# Akan tetapi memang tidak semua kolom perlu kita tangani, kita harus tetap melihat dan memahami tujuan dari setiap kolom yang ada di dataset.
#
# Terlihat pada kolom beberapa data yang memiliki outliner adalah:
# - brand_id dengan persentase 16,8 %
# - loves_count dengan persentase 11,2 %
# - rating dengan persentase 3,9 %
# - reviews dengan persentase 10,7 %
# - price_usd dengan persentase 9,9 %
# - value_price_usd dengan persentase 0,32 %
# - sale_price_usd dengan persentase 0,12 %
# - limited_edition dengan persentase 7,02 %
# - new dengan persentase 7,16 %
# - online_only dengan persentase 21,9 %
# - out_of_stock dengan persentase 7,3 %
# - child_count dengan persentase 12,9 %
# - child_max_price dengan persentase 3,7 %
# - child_min_price dengan persentase 3,8 %

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y=df['brand_id'])
plt.title('Boxplot of brand_id')
plt.ylabel('brand_id')
plt.show()

# %% [markdown]
# Berdasarkan boxplot, distribusi brand_id menunjukkan adanya beberapa outlier di nilai rendah dan tinggi, sementara sebagian besar data terkonsentrasi pada rentang tengah.

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y=df['loves_count'])
plt.title('Boxplot of loves_count')
plt.ylabel('loves_count')
plt.show()

# %% [markdown]
# Sebaran data loves_count didominasi oleh nilai rendah dengan outlier signifikan di sisi atas, menandakan adanya ketimpangan popularitas yang tinggi antar produk.

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y=df['rating'])
plt.title('Boxplot of rating')
plt.ylabel('rating')
plt.show()

# %% [markdown]
# Terlihat pada boxplot, data terkonsentrasi tinggi, menunjukkan kepuasan konsumen yang stabil. Terdapat outlier pada nilai rendah, yang mencerminkan adanya produk dengan performa di bawah standar.

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y=df['reviews'])
plt.title('Boxplot of reviews')
plt.ylabel('reviews')
plt.show()

# %% [markdown]
# Pada reviews menunjukkan pola long-tail, artinya hanya sedikit produk yang mendapatkan ulasan dalam jumlah sangat banyak, sementara sebagian besar produk lainnya hanya memiliki sedikit ulasan. Dengan kata lain, interaksi pengguna lebih banyak terfokus pada beberapa produk yang memang paling populer atau best-seller.

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y=df['price_usd'])
plt.title('Boxplot of price_usd')
plt.ylabel('price_usd')
plt.show()

# %% [markdown]
# Kalau dilihat dari distribusinya, sebagian besar produk dijual dengan harga yang masih cukup terjangkau. Tapi ada satu produk dengan harga yang jauh dari yang lain, hampir menyentuh 2.000 USD. Perbedaan ini cukup mencolok dan kemungkinan besar itu adalah produk luxury atau paket khusus yang memang dipasarkan di segmen harga yang sangat berbeda dibandingkan produk lainnya.

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y=df['value_price_usd'])
plt.title('Boxplot of value_price_usd')
plt.ylabel('value_price_usd')
plt.show()

# %% [markdown]
# Sebagian besar produk dijual dengan harga yang masih tergolong terjangkau, yaitu di bawah 150 USD. Namun, ada beberapa produk dengan harga yang jauh lebih tinggi hingga sekitar 600 USD. Titik-titik di bagian atas grafik menunjukkan adanya produk dengan harga yang cukup mencolok dibandingkan rata-rata produk lainnya.

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y=df['sale_price_usd'])
plt.title('Boxplot of sale_price_usd')
plt.ylabel('sale_price_usd')
plt.show()

# %% [markdown]
# Sebagian besar harga jual akhir produk masih tergolong terjangkau, namun terdapat satu produk dengan harga di atas 300 USD yang terlihat cukup mencolok dibandingkan yang lainnya.

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y=df['limited_edition'])
plt.title('Boxplot of limited_edition')
plt.ylabel('limited_edition')
plt.show()

# %% [markdown]
# Dari data terlihat bahwa hampir semua produk dalam koleksi ini merupakan barang reguler. Produk limited edition jumlahnya sangat sedikit, sehingga terlihat terpisah sendiri di grafik dan bisa dianggap sebagai outlier. Hal ini menunjukkan bahwa kategori Limited Edition memang sangat jarang muncul dalam dataset ini.

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y=df['new'])
plt.title('Boxplot of new')
plt.ylabel('new')
plt.show()

# %% [markdown]
# Data menunjukkan bahwa stok barang didominasi oleh produk lama. Produk dengan status New jumlahnya sangat sedikit, sehingga terlihat mencolok sendiri dan bisa dianggap sebagai outlier dalam dataset.

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y=df['online_only'])
plt.title('Boxplot of online_only')
plt.ylabel('online_only')
plt.show()

# %% [markdown]
# Sebagian besar produk tersedia di toko fisik (bernilai 0). Produk yang berstatus “online_only” (bernilai 1) jumlahnya sangat sedikit, sehingga terlihat sebagai pengecualian atau outlier dalam dataset ini.

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y=df['out_of_stock'])
plt.title('Boxplot of out_of_stock')
plt.ylabel('out_of_stock')
plt.show()

# %% [markdown]
# Sebagian besar produk masih tersedia atau memiliki stok. Produk yang berstatus “Habis” (bernilai 1) jumlahnya sangat sedikit, sehingga terlihat menonjol sendiri dan dapat dianggap sebagai outlier dalam data.

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y=df['child_count'])
plt.title('Boxplot of child_count')
plt.ylabel('child_count')
plt.show()

# %% [markdown]
# Sebagian besar produk hanya memiliki sedikit varian atau bahkan hampir tidak memiliki varian sama sekali. Namun, terdapat beberapa produk yang jumlah variannya jauh lebih banyak dibandingkan yang lain, bahkan ada satu produk yang memiliki lebih dari 100 varian, sehingga terlihat sebagai outlier dalam data.

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y=df['child_max_price'])
plt.title('Boxplot of child_max_price')
plt.ylabel('child_max_price')
plt.show()

# %% [markdown]
# Mayoritas produk memiliki harga varian tertinggi yang masih tergolong terjangkau (di bawah 100 USD), namun terdapat cukup banyak outlier dengan harga jauh lebih tinggi hingga 300–400 USD, bahkan ada satu varian yang hampir menyentuh 600 USD, yang menunjukkan adanya varian premium atau edisi khusus dengan segmen harga yang jauh di atas rata-rata.

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y=df['child_min_price'])
plt.title('Boxplot of child_min_price')
plt.ylabel('child_min_price')
plt.show()

# %% [markdown]
# Sebagian besar varian termurah dari suatu produk masih berada di bawah 50 USD, namun terdapat beberapa outlier di mana bahkan harga paling murahnya sudah tergolong tinggi, bahkan ada yang mencapai sekitar 400 USD.

# %% [markdown]
# # **Eksplorasi Data (EDA)**

# %% [markdown]
# ## **Comparison/Perbandingan**

# %%
loves_kategori = df.groupby('primary_category')['loves_count'].sum().sort_values(ascending=False)

plt.figure(figsize=(10,6))
sns.barplot(
    x=loves_kategori.index,
    y=loves_kategori.values,
    palette='viridis',
    hue=loves_kategori.index,
    legend=False
)

plt.title('Total Loves Berdasarkan Primary Category')
plt.xlabel('Primary Category')
plt.ylabel('Total Loves')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Berdasarkan grafik, kategori Makeup memiliki total loves tertinggi dibanding kategori lainnya, menunjukkan bahwa produk makeup memiliki tingkat ketertarikan dan engagement paling besar dari pengguna. Di posisi kedua terdapat Skincare, yang juga menunjukkan minat tinggi namun masih berada cukup jauh di bawah Makeup.
#
#
# Kategori seperti Hair dan Fragrance berada di tingkat menengah, sedangkan Mini Size, Bath & Body, Tools & Brushes, Men, dan Gifts memiliki total loves yang relatif rendah. Hal ini mengindikasikan bahwa fokus utama minat pengguna berada pada kategori Makeup dan Skincare, sehingga kedua kategori tersebut berpotensi menjadi kontributor utama dalam strategi promosi dan penjualan.

# %%
loves_brand = df.groupby('brand_name')['loves_count'].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(10,6))
sns.barplot(
    x=loves_brand.index,
    y=loves_brand.values,
    palette='viridis',
    hue=loves_brand.index,
    legend=False
)

plt.title('Top 10 Brand dengan Total Loves Terbanyak')
plt.xlabel('Brand')
plt.ylabel('Total Loves')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Berdasarkan grafik, SEPHORA COLLECTION menempati posisi pertama dengan total loves tertinggi, menunjukkan brand ini memiliki engagement paling kuat dibanding brand lainnya. Di posisi berikutnya terdapat Fenty Beauty by Rihanna, disusul Anastasia Beverly Hills, Charlotte Tilbury, dan The Ordinary, yang juga menunjukkan tingkat popularitas tinggi.
#
#
# Brand seperti NARS, Dior, Urban Decay, dan Rare Beauty by Selena Gomez tetap berada dalam Top 10, namun dengan total loves yang lebih rendah dibanding pemimpin pasar.
# Hal ini menunjukkan bahwa brand dengan positioning kuat, reputasi global, dan produk best-seller cenderung memiliki engagement pengguna yang lebih tinggi. Insight ini dapat dimanfaatkan untuk strategi promosi, kolaborasi brand, dan analisis dominasi pasar.

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='reviews', y='loves_count', data=df)

plt.title('Hubungan Reviews dan Loves Count')
plt.xlabel('Reviews')
plt.ylabel('Loves Count')
plt.show()

# %% [markdown]
# Berdasarkan scatter plot, terlihat adanya korelasi positif antara jumlah reviews dan loves_count. Produk dengan jumlah review yang lebih tinggi cenderung memiliki jumlah loves yang lebih besar.
#
# Sebagian besar data terkonsentrasi pada area reviews rendah hingga menengah dengan loves yang juga relatif rendah, namun terdapat beberapa outlier dengan reviews dan loves yang sangat tinggi. Hal ini menunjukkan bahwa semakin tinggi interaksi pengguna dalam bentuk review, semakin tinggi pula tingkat ketertarikan (loves), meskipun distribusinya tidak sepenuhnya linear dan terdapat variasi yang cukup besar antar produk.

# %% [markdown]
# ## **Composition/Komposisi**

# %%
loves_by_category = df.groupby('primary_category')['loves_count'].sum().sort_values(ascending=False)
loves_top3 = loves_by_category.head(3)

plt.figure(figsize=(10, 8))
loves_top3.plot(
    kind='pie',
    autopct='%1.1f%%',
    startangle=140,
    colors=plt.cm.Paired.colors
)
plt.title('Proporsi 3 Kategori Teratas Berdasarkan Total Loves')
plt.ylabel('')
plt.axis('equal')
plt.show()

# %% [markdown]
# Berdasarkan diagram pie, Makeup mendominasi dengan sekitar 60% dari total loves pada tiga kategori teratas. Hal ini menunjukkan bahwa minat dan engagement pengguna sangat terpusat pada kategori ini. Di posisi kedua terdapat Skincare dengan sekitar 30,6%, yang juga memiliki kontribusi besar namun masih jauh di bawah Makeup.
#
# Sementara itu, Hair hanya menyumbang sekitar 9,4%, menunjukkan bahwa dibanding dua kategori lainnya, tingkat ketertarikan pengguna relatif lebih rendah. Secara keseluruhan, grafik ini menegaskan bahwa engagement pengguna sangat terkonsentrasi pada kategori Makeup, menjadikannya kategori paling dominan dalam dataset.

# %% [markdown]
# ## **Distribution/Distribusi**

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['loves_count'], bins=20, kde=True, color='pink')

plt.title('Distribusi Loves Count')
plt.xlabel('Loves Count')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# Kalau dilihat dari gambar diatas, jumlah loves_count itu tidak tersebar merata dan cenderung miring ke kanan. Kebanyakan produk punya jumlah loves yang rendah, sementara hanya sedikit produk yang loves-nya sangat tinggi. Ini menunjukkan kalau popularitasnya timpang cuma beberapa produk yang benar-benar populer dan punya engagement tinggi, sedangkan sebagian besar lainnya biasa saja. Pola seperti ini sebenarnya wajar di e-commerce, karena biasanya memang hanya ada sedikit produk best-seller dan banyak produk dengan performa sedang sampai rendah.

# %% [markdown]
# ## **Relationship/Hubungan**

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(
    df[['loves_count', 'reviews', 'price_usd', 'rating']].corr(),
    annot=True,
    cmap='viridis',
    fmt='.2f'
)

plt.title('Correlation Matrix Variabel Numerik')
plt.show()

# %% [markdown]
# Berdasarkan correlation matrix, hubungan antar variabel dapat dijelaskan sebagai berikut:
#
# - Hubungan antara loves_count dan reviews memiliki korelasi positif yang cukup kuat sebesar 0.68. Hal ini menunjukkan bahwa semakin banyak ulasan yang diterima suatu produk, semakin tinggi pula jumlah loves yang diperoleh. Engagement pengguna melalui reviews berkaitan erat dengan tingkat popularitas produk.
#
# - Hubungan antara loves_count dan price_usd menunjukkan korelasi negatif yang sangat lemah (-0.09). Ini berarti harga tidak memiliki pengaruh yang signifikan terhadap jumlah loves. Produk dengan harga tinggi maupun rendah tidak menunjukkan perbedaan yang berarti dalam tingkat popularitas.
#
# - Hubungan antara loves_count dan rating memiliki korelasi positif yang sangat lemah (0.04). Artinya, meskipun rating mencerminkan kualitas produk, nilai rating tidak secara langsung berkorelasi kuat dengan jumlah loves.
#
# - Hubungan antara reviews dan price_usd juga menunjukkan korelasi negatif yang sangat lemah (-0.06), sehingga harga tidak berhubungan signifikan dengan banyaknya ulasan yang diberikan.
#
# - Hubungan antara reviews dan rating memiliki korelasi positif yang sangat lemah (0.07), yang menunjukkan bahwa produk dengan rating tinggi belum tentu memiliki jumlah reviews yang tinggi.
#
# - Terakhir, hubungan antara price_usd dan rating menunjukkan korelasi positif yang sangat lemah (0.06), sehingga harga tidak memiliki hubungan yang berarti dengan tinggi rendahnya rating.
#
#
# Secara keseluruhan, hanya hubungan antara reviews dan loves_count yang menunjukkan korelasi cukup signifikan, sementara variabel lainnya memiliki hubungan yang lemah.

# %% [markdown]
# # **Data Preparation**

# %% [markdown]
# ## **Pengecekkan Tipe Data**

# %%
df.dtypes
# Out:
# product_id             object
# product_name           object
# brand_id                int64
# brand_name             object
# loves_count             int64
# rating                float64
# reviews               float64
# size                   object
# variation_type         object
# variation_value        object
# variation_desc         object
# ingredients            object
# price_usd             float64
# value_price_usd       float64
# sale_price_usd        float64
# limited_edition         int64
# new                     int64
# online_only             int64
# out_of_stock            int64
# sephora_exclusive       int64
# highlights             object
# primary_category       object
# secondary_category     object
# tertiary_category      object
# child_count             int64
# child_max_price       float64
# child_min_price       float64
# dtype: object

# %% [markdown]
# Dilakukan penyesuaian tipe data pada kolom brand_id dari integer menjadi object. Perubahan ini dilakukan karena brand_id berfungsi sebagai identitas unik, bukan sebagai variabel numerik yang bisa dihitung secara matematis.
#
# Jika tetap dibiarkan dalam bentuk integer, kolom tersebut berpotensi ikut terlibat dalam perhitungan statistik seperti rata-rata atau penjumlahan, padahal secara konsep itu tidak relevan. Dengan mengubahnya menjadi object, kolom ini diperlakukan sebagai data kategorikal sehingga lebih sesuai dengan fungsinya sebagai penanda identitas.

# %%
df['brand_id'] = df['brand_id'].astype(str)

# %%
df.dtypes
# Out:
# product_id             object
# product_name           object
# brand_id               object
# brand_name             object
# loves_count             int64
# rating                float64
# reviews               float64
# size                   object
# variation_type         object
# variation_value        object
# variation_desc         object
# ingredients            object
# price_usd             float64
# value_price_usd       float64
# sale_price_usd        float64
# limited_edition         int64
# new                     int64
# online_only             int64
# out_of_stock            int64
# sephora_exclusive       int64
# highlights             object
# primary_category       object
# secondary_category     object
# tertiary_category      object
# child_count             int64
# child_max_price       float64
# child_min_price       float64
# dtype: object

# %% [markdown]
# Pada tahap ini, dilakukan penyesuaian tipe data pada kolom brand_id dengan menggunakan fungsi .astype(str). Tujuannya adalah mengubah tipe data yang semula integer menjadi object.
#
# Langkah ini dilakukan karena brand_id merupakan variabel identitas (ID) yang bersifat unik, bukan variabel numerik yang digunakan untuk operasi perhitungan matematis. Dengan mengubahnya ke tipe object, kolom tersebut tidak akan ikut terhitung dalam analisis statistik deskriptif seperti mean atau sum, sehingga validitas hasil analisis tetap terjaga.
#
# Sementara itu, untuk seluruh kolom lainnya, tipe data yang tersedia sudah dipastikan sesuai dengan karakteristik nilainya masing-masing, baik itu tipe numerik (float/int) untuk variabel terukur maupun tipe object untuk variabel kategorikal, sehingga untuk kolom lain tidak perlu dilakukan perubahan.

# %% [markdown]
# ### **Pengecekkan Konsistensi Penulisan pada Perubahan Tipe Data**

# %%
print(df['brand_id'].unique())
# Out:
# ['6342' '6471' '6485' '5847' '6321' '7054' '6018' '6283' '6312' '5998'
#  '7103' '6004' '5746' '6173' '1517' '6242' '6083' '6356' '2041' '5737'
#  '6272' '5938' '7075' '5333' '6025' '7086' '6195' '5687' '5644' '6487'
#  '6372' '7101' '6327' '7057' '5995' '1179' '5984' '8007' '6474' '1138'
#  '6482' '6253' '3155' '4171' '6742' '6502' '1065' '6236' '5980' '7062'
#  '6121' '7065' '2082' '5673' '1254' '6351' '7095' '6743' '7091' '6473'
#  '6503' '6322' '6349' '6484' '6353' '7006' '6486' '6131' '6136' '6219'
#  '1073' '3673' '6260' '3491' '6147' '6302' '4372' '5668' '6014' '6318'
#  '6334' '7083' '7004' '6000' '6377' '6193' '6183' '7081' '6089' '3526'
#  '6320' '6329' '8001' '6362' '6200' '6352' '5972' '6274' '6300' '7037'
#  '6468' '6347' '4348' '5864' '6328' '1133' '6369' '5996' '6751' '6189'
#  '6264' '6275' '6309' '6361' '6151' '1063' '1132' '6491' '6500' '6476'
#  '6490' '6117' '6325' '1180' '5879' '6746' '6106' '7050' '6368' '6331'
#  '6162' '6156' '7017' '6235' '6357' '6295' '8008' '6175' '3297' '2002'
#  '6035' '6335' '6202' '5922' '6254' '5841' '7070' '6469' '6472' '6255'
#  '6499' '5946' '6745' '6259' '6218' '6240' '6029' '6188' '6207' '5715'
#  '6279' '6481' '5905' '2366' '3581' '6201' '1741' '6125' '5809' '6246'
#  '6216' '6273' '5936' '6345' '6753' '6250' '7038' '4028' '6332' '6749'
#  '3680' '8017' '6744' '6376' '6287' '6338' '6134' '6315' '5606' '6226'
#  '6182' '6256' '3729' '4164' '6026' '5805' '3976' '6184' '8012' '6323'
#  '7025' '7055' '6001' '6757' '6204' '5674' '6326' '6346' '3733' '6340'
#  '6144' '6313' '1071' '6160' '6286' '6366' '6341' '6209' '3728' '3866'
#  '6252' '6114' '5764' '6310' '6756' '6330' '6155' '1164' '6475' '6317'
#  '6363' '5857' '7102' '6166' '6367' '7100' '5671' '6159' '6337' '6294'
#  '3902' '5823' '6314' '5337' '5338' '6748' '6084' '6187' '6289' '6288'
#  '6130' '3990' '6303' '6145' '6750' '5626' '3865' '6358' '6307' '6247'
#  '8020' '6073' '5987' '6360' '5780' '6225' '5648' '7020' '6041' '6238'
#  '6285' '6380' '6375' '6234' '8000' '6488' '6343' '1722' '5869' '4225'
#  '6355' '6477' '2000' '6373' '5651' '3806' '1169' '6365' '7064' '6112'
#  '2084' '5979' '6232' '6501' '6304' '7072' '6245' '6149' '6371' '6344'
#  '6316' '6470' '6169' '1070']

# %% [markdown]
# Setelah dilakukan pengecekan lebih lanjut, seluruh data pada kolom brand_id yang telah diubah menjadi tipe object menunjukkan hasil yang konsisten. Tidak ditemukan adanya kesalahan penulisan, spasi kosong, atau karakter asing di dalam kolom tersebut. Hal ini mengonfirmasi bahwa proses konversi tipe data tidak merusak struktur informasi dan dataset kini telah benar-benar bersih serta siap untuk dianalisis

# %% [markdown]
# ## **Inconsistent Values**

# %% [markdown]
# Inconsistent Values adalah kondisi ketika data dalam satu kolom memiliki perbedaan format penulisan atau tipe data, sehingga data yang sebenarnya sama terbaca sebagai dua hal yang berbeda karena penulisannya tidak seragam. Pada tahap ini, kita akan menyamakan atau menyesuaikan format penulisan dalam dataset agar data menjadi lebih rapi, konsisten, dan siap untuk diolah lebih lanjut.
#
# Terdapat 7 kolom bertipe object yaitu **ingredients**, **variation_value**, **variation_type**, **variation_desc**, **size**, **highlights**, dan **tertiary_category** yang isinya sangat tidak konsisten dan format teksnya tidak terstruktur dengan baik.
#
# Kolom-kolom ini memang tidak diproses pada tahap inconsistent values ini karena tidak berhubungan langsung dengan tujuan utama dari analisis, yang dimana dataset ini digunakan untuk lebih berfokus pada harga, rating, dan popularitas produk. Agar proses analisis lebih efisien dan penggunaan memori lebih ringan, kolom-kolom tersebut akan dihapus (drop). Dengan begitu, data yang digunakan benar-benar relevan dan analisis bisa lebih terarah.

# %%
df['product_name'] = df['product_name'].str.title()
print(df['product_name'].unique())
# Out:
# ['Fragrance Discovery Set' 'La Habana Eau De Parfum'
#  'Rainbow Bar Eau De Parfum' ... 'Mon Paris Eau De Parfum Gift Set'
#  'Y Eau De Parfum Gift Set'
#  'Candy Glaze Lip Gloss Stick Duo With Hyaluronic Acid']

# %% [markdown]
# Penulisan pada kolom product_name sudah diperbaiki. Pada tahap ini, saya menggunakan format title, yaitu huruf kapital di awal setiap kata (Capitalize Each Word). Setelah dilakukan penyesuaian, seluruh data pada product_name kini sudah memiliki format penulisan yang seragam dan konsisten.

# %%
df['brand_name'] = df['brand_name'].str.title()
print(df['brand_name'].unique())
# Out:
# ['19-69' '54 Thrones' 'Abbott' 'Acqua Di Parma' 'Adwoa Beauty' 'Aerin'
#  'Algenist' 'Alpha-H' 'Alpyn Beauty' 'Alterna Haircare' 'Ami Colé' 'Amika'
#  'Anastasia Beverly Hills' 'Aquis' 'Armani Beauty' 'Artist Couture'
#  'Atelier Cologne' 'Augustinus Bader' 'Azzaro' 'Bareminerals' 'Beautybio'
#  'Beautyblender' 'Belif' 'Benefit Cosmetics' 'Berdoues' 'Bio Ionic'
#  'Biossance' 'Blinc' 'Bobbi Brown' 'Bon Parfumeur' 'Bondiboost'
#  'Boy Smells' 'Bread Beauty Supply' 'Briogeo' 'Bumble And Bumble'
#  'Burberry' 'Buxom' 'By Rosie Jane' 'Caliray' 'Calvin Klein' 'Canopy'
#  'Capri Blue' 'Carolina Herrera' 'Caudalie' 'Cay Skin' 'Ceremonia'
#  'Chanel' 'Charlotte Tilbury' 'Chloé' 'Christian Louboutin'
#  'Christophe Robin' 'Cinema Secrets' 'Clarins' 'Clean Reserve' 'Clinique'
#  'Color Wow' 'Commodity' 'Community Sixty-Six' 'Coola' 'Crown Affair'
#  'Curlsmith' 'Dae' 'Damdam' 'Dame' 'Danessa Myricks Beauty'
#  'Deborah Lippmann' 'Dedcool' 'Derek Lam 10 Crosby' 'Dermaflash'
#  'Dermalogica' 'Dior' 'Dolce&Gabbana' 'Dominique Cosmetics' 'Donna Karan'
#  'Dphue' 'Dr. Barbara Sturm' 'Dr. Brandt Skincare'
#  'Dr. Dennis Gross Skincare' 'Dr. Jart+'
#  'Dr. Lara Devgan Scientific Beauty' 'Dr. Zenovia Skincare'
#  'Drunk Elephant' 'Drybar' 'Duo' 'Eadem' 'Eight & Bob' 'Ellis Brooklyn'
#  'Erno Laszlo' 'Estée Lauder' 'Evian' 'Fable & Mane' 'Facegym' 'Farmacy'
#  'Fashion Fair' 'Fenty Beauty By Rihanna' 'Fenty Skin' 'First Aid Beauty'
#  'Flora + Bast' 'Floral Street' 'Foreo' 'Forvr Mood' 'Freck Beauty'
#  'Fresh' 'Ghd' 'Gisou' 'Givenchy' 'Glamnetic' 'Glo Science' 'Glossier'
#  'Glow Recipe' 'Good Dye Young' 'Google' 'Goop' 'Grace Eleyae'
#  'Grande Cosmetics' 'Gucci' 'Guerlain' 'Gxve By Gwen Stefani' 'Habit'
#  'Hanni' 'Haus Labs By Lady Gaga' 'Herbivore' 'Heretic' 'Hermès'
#  'Hourglass' 'House Of Lashes' 'Huda Beauty' 'Hum Nutrition' 'Hyper Skin'
#  'Iconic London' 'Igk' 'Ilia' 'Iluminage' 'Inc.Redible'
#  'Innbeauty Project' 'Innisfree' 'Isle Of Paradise' 'It Cosmetics'
#  'Jack Black' 'Jillian Dempsey' 'Jimmy Choo' 'Jlo Beauty'
#  'Jo Malone London' 'Josie Maran' 'Jouer Cosmetics' 'Juicy Couture'
#  'Juliette Has A Gun' 'Jvn' 'K18 Biomimetic Hairscience' 'Kaja'
#  'Kate Mcleod' 'Kate Somerville' 'Kayali' 'Kérastase' "Kiehl'S Since 1851"
#  'Kilian Paris' 'Koh Gen Do' 'Kopari' 'Kora Organics' 'Korres' 'Kosas'
#  'Kulfi' 'Kvd Beauty' "L'Occitane" "L'Oreal Professionnel" 'La Mer'
#  'Lancôme' 'Laneige' 'Laura Mercier' 'Lawless' 'Lilah B.' 'Lilly Lashes'
#  'Living Proof' 'Lys Beauty' 'Macrene Actives' 'Maison Louis Marie'
#  'Maison Margiela' 'Make Up For Ever' 'Makeup By Mario' 'Mara'
#  'Marc Jacobs Fragrances' 'Mario Badescu' 'Maude' 'Melanin Haircare'
#  'Melt Cosmetics' 'Merit' 'Milk Makeup' 'Mizani' 'Montblanc' 'Moon Juice'
#  'Moroccanoil' 'Mount Lai' 'Mugler' 'Murad' 'Nails Inc.'
#  'Narciso Rodriguez' 'Nars' 'Natasha Denona' 'Naturally Serious'
#  'Nécessaire' 'Nest New York' 'Nudestix' 'Nuface' 'Nutrafol' 'Olaplex'
#  'Olehenriksen' 'One/Size By Patrick Starrr' 'Oribe' 'Origins' 'Otherland'
#  'Ouai' 'Overose' 'Paco Rabanne' 'Pat Mcgrath Labs' 'Patrick Ta'
#  'Pattern By Tracee Ellis Ross' "Paula'S Choice" 'Peace Out'
#  'Peter Thomas Roth' 'Philosophy' 'Phlur' 'Pmd' 'Prada' 'Prima'
#  'Proven Skincare' 'Pureology' 'Rahua' 'Ralph Lauren' 'Ranavat'
#  'Rare Beauty By Selena Gomez' 'Refy' 'Ren Clean Skincare' 'Ries'
#  'Rms Beauty' 'Rose Inc' 'Rose Ingleton Md' 'Rosebud Perfume Co.'
#  'Rossano Ferretti Parma' 'Saie' 'Saint Jane Beauty' 'Sephora Collection'
#  'Sephora Favorites' 'Shani Darden Skin Care' 'Shiseido' 'Shu Uemura'
#  'Simihaze Beauty' 'Sk-Ii' 'Skin Laundry' 'Skinfix' 'Skylar' 'Slip'
#  'Smashbox' 'Sobel Skin Rx' 'Sol De Janeiro' 'Soleil Toujours'
#  'St. Tropez' 'Stila' 'Strivectin' 'Sulwhasoo' 'Summer Fridays'
#  'Sunday Ii Sunday' 'Sunday Riley' 'Supergoop!' 'Susteau' 'T3' 'Tan-Luxe'
#  'Tarte' 'Tata Harper' 'Tatcha' 'The 7 Virtues' 'The Inkey List'
#  'The Maker' 'The Nue Co.' 'The Ordinary' 'The Original Makeup Eraser'
#  'The Outset' 'The Phluid Project' 'Tocca' 'Tom Ford' 'Too Faced'
#  'Topicals' 'Touchland' 'Tower 28 Beauty' 'Tula Skincare' 'Tweezerman'
#  'Urban Decay' 'Valentino' 'Vegamour' 'Velour Lashes' 'Verb' 'Versace'
#  'Viktor&Rolf' 'Violet Voss' 'Viori' 'Virtue' 'Viseart' 'Voluspa'
#  'Wander Beauty' 'Waso' 'Westman Atelier' 'Wishful'
#  'World Of Chris Collins' 'Youth To The People' 'Yves Saint Laurent']

# %% [markdown]
# Penulisan pada kolom brand_name juga sudah diperbaiki. Pada tahap ini, saya menggunakan format yang sama dengan sebelumnya yaitu format title, huruf kapital di awal setiap kata (Capitalize Each Word). Setelah dilakukan penyesuaian, seluruh data pada brand_name kini sudah memiliki format penulisan yang seragam dan konsisten.

# %%
df['primary_category'] = df['primary_category'].str.strip().str.title()
print(df['primary_category'].unique())
# Out:
# ['Fragrance' 'Bath & Body' 'Mini Size' 'Hair' 'Makeup' 'Skincare'
#  'Tools & Brushes' 'Men' 'Gifts']

# %% [markdown]
# Penulisan pada kolom primary_category, dilakukan proses standarisasi seperti pada kolom-kolom sebelumnya. Walaupun sekilas datanya sudah terlihat rapi, tetapi disini saya tetap lakukan proses penyamaan penulisan dengan mengubah format penulisannya menjadi title serta menghapus spasi berlebih di awal atau akhir teks.
#
# Langkah ini bertujuan untuk memastikan kategori utama seperti Makeup, Skincare, dan Fragrance memiliki penulisan yang konsisten. Dengan penulisan yang seragam, proses pengelompokan produk pada tahap analisis menjadi lebih akurat dan terhindar dari duplikasi kategori yang sebenarnya sama tetapi berbeda format penulisannya.

# %%
df['secondary_category'] = df['secondary_category'].str.strip().str.title()
print(df['secondary_category'].unique())
# Out:
# ['Value & Gift Sets' 'Women' 'Body Moisturizers' 'Fragrance' 'Men'
#  'Candles & Home Scents' 'Body Care' 'Hair Styling & Treatments'
#  'Shampoo & Conditioner' 'Mini Size' 'Lip' 'Moisturizers' 'Treatments'
#  'Eye Care' 'Lip Balms & Treatments' 'Sunscreen' 'Cleansers' 'Masks'
#  'Skincare' 'Face' 'Eye' 'Cheek' 'Hair' 'Tools' 'Brushes & Applicators'
#  'Makeup Palettes' 'Beauty Tools' 'Accessories' 'Makeup' 'Bath & Shower'
#  'Wellness' 'High Tech Tools' 'Shop By Concern' nan 'Self Tanners'
#  'Shaving' 'Hair Tools' 'Nail' 'Beauty Accessories' 'Beauty Supplements'
#  'Other Needs' 'Bath & Body']

# %% [markdown]
# Penulisan pada kolom ini juga dilakukan standarisasi secara menyeluruh dengan mengubah semua teks ke format title dan menghapus spasi yang tidak perlu di awal atau akhir kata.
#
# Karena kolom ini punya variasi nilai yang jauh lebih banyak dan lebih spesifik dibanding kategori utama, proses ini jadi sangat penting. Soalnya kalau ada perbedaan penulisan sedikit saja, datanya bisa terbaca sebagai kategori yang berbeda padahal sebenarnya sama.
#
# Dengan penulisan yang sudah diseragamkan, analisis detail per jenis produk bisa dilakukan dengan lebih maksimal dan tidak ada lagi data yang terpecah cuma karena beda format penulisan.

# %% [markdown]
# ## **Missing Values**

# %% [markdown]
# Missing values adalah kondisi ketika terdapat nilai yang kosong, tidak terisi, atau hilang dalam suatu kolom pada dataset. Pada tahap ini kita harus tangani data data yang hilang agar ketika kita menggunakan data yang ada data jadi tidak bias saat digunakan.

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#                     Null Ratio in %
# product_id                 0.000000
# product_name               0.000000
# brand_id                   0.000000
# brand_name                 0.000000
# loves_count                0.000000
# rating                     3.272899
# reviews                    3.272899
# size                      19.201789
# variation_type            17.000235
# variation_value           18.813280
# variation_desc            85.283730
# ingredients               11.125500
# price_usd                  0.000000
# value_price_usd           94.690370
# sale_price_usd            96.821286
# limited_edition            0.000000
# new                        0.000000
# online_only                0.000000
# out_of_stock               0.000000
# sephora_exclusive          0.000000
# highlights                25.983047
# primary_category           0.000000
# secondary_category         0.094184
# tertiary_category         11.655286
# child_count                0.000000
# child_max_price           67.577113
# child_min_price           67.577113

# %% [markdown]
# Beberapa kolom seperti value_price_usd, sale_price_usd, variation_desc, child_max_price, dan child_min_price memiliki persentase missing values yang sangat tinggi (di atas 60%). Selain itu, ada juga kolom seperti highlights, size, variation_value, variation_type, tertiary_category, dan ingredients yang jumlah data kosongnya cukup banyak.
#
# Kolom-kolom tersebut tidak dilakukan perbaikan atau pengisian data karena memang tidak terlalu relevan dengan tujuan utama analisis. Oleh karena itu, kolom-kolom ini akan dihapus pada tahap akhir pembersihan data agar analisis lebih fokus pada variabel yang memiliki kualitas data lebih baik dan benar-benar mendukung tujuan penelitian.
#
# Sementara itu, untuk menjaga integritas data, dilakukan imputasi (pengisian) pada tiga kolom utama yaitu **rating**, **reviews**, dan **secondary_category**, di mana penentuan nilai pengisinya didasarkan pada karakteristik distribusi data serta tipe data masing-masing kolom

# %% [markdown]
# ### **Rating**

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['rating'].dropna(), kde=True, color='skyblue', bins=20)
plt.axvline(df['rating'].mean(), color='red', linestyle='--', label=f'Mean: {df["rating"].mean():.2f}')
plt.axvline(df['rating'].median(), color='green', linestyle='-', label=f'Median: {df["rating"].median():.2f}')

plt.title('Distribusi Data Rating (Sebelum Imputasi)', fontsize=14)
plt.xlabel('Rating', fontsize=12)
plt.ylabel('Frekuensi', fontsize=12)
plt.legend()

plt.show()

# %% [markdown]
# Berdasarkan bentuk histogram, variabel rating terlihat memiliki distribusi skewed left (miring ke kiri). Hal ini bisa dilihat dari nilai mean yang lebih kecil dibanding median (4,20 < 4,29). Artinya, ada beberapa nilai rendah yang menarik rata-rata ke bawah.
#
# Karena distribusinya memiliki ekor di sisi kiri, penggunaan median sebagai nilai imputasi lebih tepat. Median cenderung lebih stabil dan tidak mudah terpengaruh oleh nilai ekstrem, sehingga tetap merepresentasikan area dengan frekuensi data terbanyak. Dengan begitu, proses pengisian data tidak menjadi bias akibat adanya pencilan bernilai rendah.

# %%
df['rating'] = df['rating'].fillna(df['rating'].dropna().median())

# %% [markdown]
# ### **Reviews**

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['reviews'].dropna(), kde=True, color='orange', bins=30)
plt.axvline(df['reviews'].mean(), color='red', linestyle='--', label=f'Mean: {df["reviews"].mean():.2f}')
plt.axvline(df['reviews'].median(), color='green', linestyle='-', label=f'Median: {df["reviews"].median():.2f}')

plt.title('Distribusi Data Reviews (Sebelum Imputasi)', fontsize=14)
plt.xlabel('Jumlah Reviews', fontsize=12)
plt.ylabel('Frekuensi', fontsize=12)
plt.legend()

plt.show()

# %% [markdown]
# Variabel reviews menunjukkan distribusi skewed right (miring ke kanan) yang cukup ekstrem. Ini terlihat dari nilai mean (448,55) yang jauh lebih besar dibanding median (122,00). Perbedaan ini terjadi karena ada beberapa produk dengan jumlah ulasan yang sangat tinggi sehingga menarik rata-rata ke atas.
#
# Karena distribusinya condong ke kanan, median lebih tepat digunakan sebagai nilai imputasi. Median lebih mampu merepresentasikan kondisi mayoritas data dan tidak terlalu terpengaruh oleh nilai ekstrem. Dengan begitu, proses pengisian data menjadi lebih akurat dan tetap mencerminkan pola umum jumlah ulasan produk.

# %%
df['reviews'] = df['reviews'].fillna(df['reviews'].dropna().median())

# %% [markdown]
# ### **Secondary Category**

# %%
modus_kategori = df['secondary_category'].mode()[0]

df['secondary_category'] = df['secondary_category'].fillna(modus_kategori)
print(f"Data kosong diisi dengan kategori: {modus_kategori}")
# Out:
# Data kosong diisi dengan kategori: Women

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#                     Null Ratio in %
# product_id                 0.000000
# product_name               0.000000
# brand_id                   0.000000
# brand_name                 0.000000
# loves_count                0.000000
# rating                     0.000000
# reviews                    0.000000
# size                      19.201789
# variation_type            17.000235
# variation_value           18.813280
# variation_desc            85.283730
# ingredients               11.125500
# price_usd                  0.000000
# value_price_usd           94.690370
# sale_price_usd            96.821286
# limited_edition            0.000000
# new                        0.000000
# online_only                0.000000
# out_of_stock               0.000000
# sephora_exclusive          0.000000
# highlights                25.983047
# primary_category           0.000000
# secondary_category         0.000000
# tertiary_category         11.655286
# child_count                0.000000
# child_max_price           67.577113
# child_min_price           67.577113

# %% [markdown]
# Terlihat pada data di atas bahwa missing values pada kolom **rating**, **reviews**, dan **secondary_category** sudah kita atasi dan sekarang nilainya sudah di angka 0 semua. Hal ini berarti sudah tidak ada lagi data yang kosong (missing values) pada variabel-variabel kunci dalam dataset kita, sehingga data siap digunakan untuk tahap analisis selanjutnya.

# %% [markdown]
# ## **Duplicated Values**

# %% [markdown]
# Duplicated values adalah kondisi ketika terdapat data yang tercatat lebih dari satu kali dalam dataset, sehingga menghasilkan baris atau nilai yang sama (duplikat). Pada tahap ini, kita akan memastikan apakah pada dataset yang kita gunakan memiliki nilai yang terduplikat, jika iya, maka nilai tersebut harus di hapus agar tidak mempengaruhi hasil analisis.

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, brand_id, brand_name, loves_count, rating, reviews, size, variation_type, variation_value, variation_desc, ingredients, price_usd, value_price_usd, sale_price_usd, limited_edition, new, online_only, out_of_stock, sephora_exclusive, highlights, primary_category, secondary_category, tertiary_category, child_count, child_max_price, child_min_price]
# Index: []
#
# [0 rows x 27 columns]

# %% [markdown]
# Dari output yang ditampilkan, hasil pengecekan data duplikat menunjukkan 0 baris, artinya tidak ada duplicated values dalam dataset.
#
# Dengan demikian, dapat dipastikan bahwa setiap baris data bersifat unik dan tidak terdapat input ganda. Hal ini penting karena data duplikat bisa memengaruhi perhitungan statistik dan membuat hasil analisis menjadi bias. Karena tidak ditemukan duplikasi, dataset sudah aman untuk digunakan pada tahap analisis selanjutnya.

# %% [markdown]
# ## **Outliers**

# %% [markdown]
# Outliers adalah nilai data yang angkanya jauh lebih besar atau lebih kecil dibandingkan sebagian besar data lainnya. Sederhananya, outlier itu data yang “menyimpang” dari pola umum. Pada tahap ini kita harus mengetahui dulu outliers yang ada pada satu data terjadi dikarenakan hal apa, lalu kita putuskan apakah perlu dihapus, dibiarkan, atau ditransformasi agar tidak mempengaruhi hasil analisis.

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom              Persentase Outliers
# loves_count                  11.196138
# rating                        4.509065
# reviews                      11.337415
# price_usd                     9.948199
# value_price_usd               0.329644
# sale_price_usd                0.129503
# limited_edition               7.028491
# new                           7.169767
# online_only                  21.909583
# out_of_stock                  7.369908
# sephora_exclusive             0.000000
# child_count                  12.962091
# child_max_price               3.790911
# child_min_price               3.802684

# %% [markdown]
# Berdasarkan hasil identifikasi menggunakan metode statistik dan visualisasi, ditemukan beberapa variabel dengan persentase outliers yang bervariasi, seperti online_only (21,90%), brand_id (16,78%), child_count (12,96%), reviews (11,33%), loves_count (11,19%), price_usd (9,94%), out_of_stock (7,36%), new (7,16%), dan limited_edition (7,02%), serta beberapa variabel lainnya dengan persentase di bawah 5%. Namun, penanganan tidak dilakukan secara seragam, melainkan disesuaikan dengan peran dan relevansi masing-masing variabel terhadap tujuan utama analisis, yaitu harga, rating, dan popularitas produk.
#
# Untuk variabel seperti online_only, child_count, out_of_stock, child_max_price, child_min_price, value_price_usd, sale_price_usd, limited_edition, serta new, tidak dilakukan treatment khusus terhadap outliers karena kolom-kolom tersebut akan dihapus pada tahap akhir pembersihan data. Variabel-variabel ini hanya merepresentasikan atribut atau status tambahan produk dan tidak termasuk dalam fokus utama analisis, yaitu harga, rating, dan popularitas. Oleh karena itu, keberadaan outliers di dalamnya tidak memerlukan penanganan lanjutan.
#
# Khusus untuk brand_id, meskipun terdeteksi memiliki persentase outliers yang cukup tinggi, tidak dilakukan pemotongan (clipping) berdasarkan metode Interquartile Range (IQR). Hal ini karena brand_id merupakan variabel identitas (ID) yang bersifat nominal. Angka pada kolom tersebut hanya berfungsi sebagai label unik untuk setiap merek dan tidak memiliki makna matematis. Melakukan pemotongan justru berisiko mengubah identitas merek dan mengganggu proses mapping data pada tahap analisis berikutnya. Untuk menghindari kesalahan interpretasi sebagai variabel numerik, kolom ini dikonversi ke tipe data object.
#
# Sementara itu, pada variabel utama seperti reviews, loves_count, rating, dan price_usd, nilai outliers sengaja dipertahankan (retained). Outliers pada variabel ini dikategorikan sebagai natural outliers karena mencerminkan kondisi pasar yang nyata. Dalam konteks e-commerce seperti Sephora, wajar apabila terdapat produk yang sangat populer atau viral sehingga memiliki jumlah ulasan dan interaksi jauh di atas rata-rata, serta produk dengan harga premium yang berada di luar rentang umum. Menghapus nilai-nilai tersebut justru dapat menghilangkan informasi penting terkait dinamika popularitas dan segmentasi harga produk di pasar.
#
# Secara keseluruhan, pendekatan penanganan outliers dilakukan secara selektif dan berbasis relevansi, sehingga kualitas data tetap terjaga tanpa mengorbankan validitas informasi yang merepresentasikan kondisi pasar secara aktual.

# %% [markdown]
# ## **Construct Data**

# %% [markdown]
# Pada analisis ini, tahap construct data tidak dilakukan karena variabel yang tersedia dalam dataset asli sudah cukup representatif untuk menjawab seluruh tujuan analisis. Atribut utama seperti price_usd, rating, reviews, dan loves_count telah menyediakan informasi yang memadai untuk mengkaji harga, penilaian, serta tingkat popularitas produk tanpa perlu membentuk variabel turunan tambahan.
#
# Fokus analisis lebih diarahkan pada peningkatan kualitas data melalui proses pembersihan yang sistematis, penanganan outliers secara selektif, serta evaluasi distribusi data agar hasil yang diperoleh lebih akurat dan dapat diinterpretasikan dengan tepat. Keputusan untuk tidak menambahkan variabel baru diambil guna menjaga kesederhanaan model sekaligus menghindari kompleksitas yang tidak diperlukan. Dengan mempertahankan struktur data yang tetap orisinal namun telah melalui tahap cleaning yang ketat, analisis dapat dilakukan secara lebih terarah, objektif, dan tetap selaras dengan tujuan awal tanpa memperluas cakupan secara berlebihan.

# %% [markdown]
# ## **Data Reduction**

# %% [markdown]
# Tahap Data Reduction dilakukan untuk meningkatkan efisiensi analisis dengan mengeliminasi atribut yang tidak relevan, bersifat redundan, atau memiliki kontribusi minimal terhadap tujuan analisis. Pada tahap ini, dilakukan pengurangan dimensi data secara signifikan melalui penghapusan 17 kolom, yang mencakup variabel teknis terkait varian produk, detail komposisi seperti ingredients, serta atribut status tambahan seperti new dan limited_edition.
#
# Keputusan ini didasarkan pada pertimbangan bahwa variabel-variabel tersebut tidak memiliki keterkaitan langsung dengan analisis hubungan antara harga (price_usd), penilaian (rating), dan popularitas (reviews serta loves_count). Selain itu, beberapa variabel yang memiliki persentase missing values atau outliers tinggi namun tidak relevan juga dihapus guna menghindari potensi bias serta mengurangi beban komputasi yang tidak diperlukan.
#
# Hasil dari tahap ini adalah dataset akhir yang lebih ringkas dan terfokus, namun tetap mempertahankan variabel inti dengan bobot informasi tinggi. Dengan struktur yang lebih sederhana, proses analisis menjadi lebih efisien tanpa mengorbankan validitas maupun kedalaman interpretasi hasil.

# %%
df = df.drop('variation_type', axis=1)

# %%
df = df.drop('variation_value', axis=1)

# %%
df = df.drop('variation_desc', axis=1)

# %%
df = df.drop('ingredients', axis=1)

# %%
df = df.drop('highlights', axis=1)

# %%
df = df.drop('size', axis=1)

# %%
df = df.drop('tertiary_category', axis=1)

# %%
df = df.drop('value_price_usd', axis=1)

# %%
df = df.drop('sale_price_usd', axis=1)

# %%
df = df.drop('out_of_stock', axis=1)

# %%
df = df.drop('online_only', axis=1)

# %%
df = df.drop('sephora_exclusive', axis=1)

# %%
df = df.drop('limited_edition', axis=1)

# %%
df = df.drop('new', axis=1)

# %%
df = df.drop('child_count', axis=1)

# %%
df = df.drop('child_max_price', axis=1)

# %%
df = df.drop('child_min_price', axis=1)

# %% [markdown]
# Sebanyak 17 kolom dihapus karena tidak relevan dengan fokus analisis yang menitikberatkan pada harga, rating, dan popularitas produk. Kolom-kolom tersebut seperti detail varian, ingredients, serta status pemasaran seperti new dan limited_edition—hanya merupakan atribut tambahan yang tidak berkontribusi signifikan dalam menganalisis hubungan antarvariabel utama maupun pola perilaku konsumen secara umum.

# %% [markdown]
# # **Matplotlib & Seaborn**

# %% [markdown]
# ## **Memuat Dataset Bersih**

# %%
file = '/content/[bersih]sephora_product_popularity.csv'

df = pd.read_csv(file)

df
# Out:
#      product_id                                       product_name  brand_id  \
# 0       P473671                            Fragrance Discovery Set      6342
# 1       P473668                            La Habana Eau de Parfum      6342
# 2       P473662                          Rainbow Bar Eau de Parfum      6342
# 3       P473660                               Kasbah Eau de Parfum      6342
# 4       P473658                          Purple Haze Eau de Parfum      6342
# ...         ...                                                ...       ...
# 8489    P467659                   Couture Clutch Eyeshadow Palette      1070
# 8490    P500874                              L'Homme Eau de Parfum      1070
# 8491    P504428                   Mon Paris Eau de Parfum Gift Set      1070
# 8492    P504448                           Y Eau de Parfum Gift Set      1070
# 8493    P505461  Candy Glaze Lip Gloss Stick Duo with Hyaluroni...      1070
#
#               brand_name  loves_count  rating  reviews             size  \
# 0                  19-69         6320  3.6364     11.0              NaN
# 1                  19-69         3827  4.1538     13.0   3.4 oz/ 100 mL
# 2                  19-69         3253  4.2500     16.0   3.4 oz/ 100 mL
# 3                  19-69         3018  4.4762     21.0   3.4 oz/ 100 mL
# 4                  19-69         2691  3.2308     13.0   3.4 oz/ 100 mL
# ...                  ...          ...     ...      ...              ...
# 8489  Yves Saint Laurent         2790  4.4286      7.0              NaN
# 8490  Yves Saint Laurent         2319  4.6367    556.0     2 oz / 60 mL
# 8491  Yves Saint Laurent         1475  5.0000      2.0              NaN
# 8492  Yves Saint Laurent          840     NaN      NaN              NaN
# 8493  Yves Saint Laurent          193     NaN      NaN  .11 oz / 3.2 mL
#
#                           variation_type                   variation_value  \
# 0                                    NaN                               NaN
# 1     Size + Concentration + Formulation                    3.4 oz/ 100 mL
# 2     Size + Concentration + Formulation                    3.4 oz/ 100 mL
# 3     Size + Concentration + Formulation                    3.4 oz/ 100 mL
# 4     Size + Concentration + Formulation                    3.4 oz/ 100 mL
# ...                                  ...                               ...
# 8489                                 NaN                               NaN
# 8490  Size + Concentration + Formulation  2 oz / 60 mL eau de parfum spray
# 8491                                 NaN                               NaN
# 8492                                 NaN                               NaN
# 8493                               Color                               NaN
#
#       ... online_only out_of_stock  sephora_exclusive  \
# 0     ...           1            0                  0
# 1     ...           1            0                  0
# 2     ...           1            0                  0
# 3     ...           1            0                  0
# 4     ...           1            0                  0
# ...   ...         ...          ...                ...
# 8489  ...           0            0                  0
# 8490  ...           0            0                  0
# 8491  ...           1            1                  0
# 8492  ...           1            0                  0
# 8493  ...           1            0                  1
#
#                                              highlights  primary_category  \
# 0     ['Unisex/ Genderless Scent', 'Warm &Spicy Scen...         Fragrance
# 1     ['Unisex/ Genderless Scent', 'Layerable Scent'...         Fragrance
# 2     ['Unisex/ Genderless Scent', 'Layerable Scent'...         Fragrance
# 3     ['Unisex/ Genderless Scent', 'Layerable Scent'...         Fragrance
# 4     ['Unisex/ Genderless Scent', 'Layerable Scent'...         Fragrance
# ...                                                 ...               ...
# 8489                                                NaN            Makeup
# 8490        ['Layerable Scent', 'Woody & Earthy Scent']         Fragrance
# 8491                                                NaN         Fragrance
# 8492                                                NaN         Fragrance
# 8493  ['Hyaluronic Acid', 'High Shine Finish', 'Plum...            Makeup
#
#       secondary_category  tertiary_category  child_count  child_max_price  \
# 0      Value & Gift Sets  Perfume Gift Sets            0              NaN
# 1                  Women            Perfume            2             85.0
# 2                  Women            Perfume            2             75.0
# 3                  Women            Perfume            2             75.0
# 4                  Women            Perfume            2             75.0
# ...                  ...                ...          ...              ...
# 8489                 Eye       Eye Palettes            0              NaN
# 8490                 Men            Cologne            1            129.0
# 8491   Value & Gift Sets  Perfume Gift Sets            0              NaN
# 8492   Value & Gift Sets  Cologne Gift Sets            0              NaN
# 8493                 Lip          Lip Gloss            0              NaN
#
#       child_min_price
# 0                 NaN
# 1                30.0
# 2                30.0
# 3                30.0
# 4                30.0
# ...               ...
# 8489              NaN
# 8490            129.0
# 8491              NaN
# 8492              NaN
# 8493              NaN
#
# [8494 rows x 27 columns]

# %%
df.tail()
# Out:
#      product_id                                       product_name  brand_id  \
# 8489    P467659                   Couture Clutch Eyeshadow Palette      1070
# 8490    P500874                              L'Homme Eau de Parfum      1070
# 8491    P504428                   Mon Paris Eau de Parfum Gift Set      1070
# 8492    P504448                           Y Eau de Parfum Gift Set      1070
# 8493    P505461  Candy Glaze Lip Gloss Stick Duo with Hyaluroni...      1070
#
#               brand_name  loves_count  rating  reviews             size  \
# 8489  Yves Saint Laurent         2790  4.4286      7.0              NaN
# 8490  Yves Saint Laurent         2319  4.6367    556.0     2 oz / 60 mL
# 8491  Yves Saint Laurent         1475  5.0000      2.0              NaN
# 8492  Yves Saint Laurent          840     NaN      NaN              NaN
# 8493  Yves Saint Laurent          193     NaN      NaN  .11 oz / 3.2 mL
#
#                           variation_type                   variation_value  \
# 8489                                 NaN                               NaN
# 8490  Size + Concentration + Formulation  2 oz / 60 mL eau de parfum spray
# 8491                                 NaN                               NaN
# 8492                                 NaN                               NaN
# 8493                               Color                               NaN
#
#       ... online_only out_of_stock  sephora_exclusive  \
# 8489  ...           0            0                  0
# 8490  ...           0            0                  0
# 8491  ...           1            1                  0
# 8492  ...           1            0                  0
# 8493  ...           1            0                  1
#
#                                              highlights  primary_category  \
# 8489                                                NaN            Makeup
# 8490        ['Layerable Scent', 'Woody & Earthy Scent']         Fragrance
# 8491                                                NaN         Fragrance
# 8492                                                NaN         Fragrance
# 8493  ['Hyaluronic Acid', 'High Shine Finish', 'Plum...            Makeup
#
#       secondary_category  tertiary_category  child_count  child_max_price  \
# 8489                 Eye       Eye Palettes            0              NaN
# 8490                 Men            Cologne            1            129.0
# 8491   Value & Gift Sets  Perfume Gift Sets            0              NaN
# 8492   Value & Gift Sets  Cologne Gift Sets            0              NaN
# 8493                 Lip          Lip Gloss            0              NaN
#
#       child_min_price
# 8489              NaN
# 8490            129.0
# 8491              NaN
# 8492              NaN
# 8493              NaN
#
# [5 rows x 27 columns]

# %%
df.head()
# Out:
#   product_id               product_name  brand_id brand_name  loves_count  \
# 0    P473671    Fragrance Discovery Set      6342      19-69         6320
# 1    P473668    La Habana Eau de Parfum      6342      19-69         3827
# 2    P473662  Rainbow Bar Eau de Parfum      6342      19-69         3253
# 3    P473660       Kasbah Eau de Parfum      6342      19-69         3018
# 4    P473658  Purple Haze Eau de Parfum      6342      19-69         2691
#
#    rating  reviews            size                      variation_type  \
# 0  3.6364     11.0             NaN                                 NaN
# 1  4.1538     13.0  3.4 oz/ 100 mL  Size + Concentration + Formulation
# 2  4.2500     16.0  3.4 oz/ 100 mL  Size + Concentration + Formulation
# 3  4.4762     21.0  3.4 oz/ 100 mL  Size + Concentration + Formulation
# 4  3.2308     13.0  3.4 oz/ 100 mL  Size + Concentration + Formulation
#
#   variation_value  ... online_only out_of_stock  sephora_exclusive  \
# 0             NaN  ...           1            0                  0
# 1  3.4 oz/ 100 mL  ...           1            0                  0
# 2  3.4 oz/ 100 mL  ...           1            0                  0
# 3  3.4 oz/ 100 mL  ...           1            0                  0
# 4  3.4 oz/ 100 mL  ...           1            0                  0
#
#                                           highlights  primary_category  \
# 0  ['Unisex/ Genderless Scent', 'Warm &Spicy Scen...         Fragrance
# 1  ['Unisex/ Genderless Scent', 'Layerable Scent'...         Fragrance
# 2  ['Unisex/ Genderless Scent', 'Layerable Scent'...         Fragrance
# 3  ['Unisex/ Genderless Scent', 'Layerable Scent'...         Fragrance
# 4  ['Unisex/ Genderless Scent', 'Layerable Scent'...         Fragrance
#
#    secondary_category  tertiary_category  child_count  child_max_price  \
# 0   Value & Gift Sets  Perfume Gift Sets            0              NaN
# 1               Women            Perfume            2             85.0
# 2               Women            Perfume            2             75.0
# 3               Women            Perfume            2             75.0
# 4               Women            Perfume            2             75.0
#
#    child_min_price
# 0              NaN
# 1             30.0
# 2             30.0
# 3             30.0
# 4             30.0
#
# [5 rows x 27 columns]

# %% [markdown]
# ## **Bar Chart**

# %%
top_10_brands = df.groupby('brand_name')['loves_count'].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(12, 7))

sns.barplot(
    x=top_10_brands.values, # Total Loves
    y=top_10_brands.index,  # Nama Brand
    hue=top_10_brands.index,
    palette='magma',        # Warna
    legend=False
)

plt.title('Top 10 Brand Berdasarkan Total Loves', fontsize=14, pad=20)
plt.xlabel('Total Loves Count', fontsize=12)
plt.ylabel('Nama Brand', fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Insight**

# %% [markdown]
# Berdasarkan bar chart Top 10 Brand Berdasarkan Total Loves, terlihat bahwa Sephora Collection menempati posisi pertama dengan jumlah loves paling tinggi dibandingkan brand lainnya. Hal ini menunjukkan bahwa produk dari brand internal Sephora memiliki tingkat popularitas yang sangat besar di kalangan pengguna. Di posisi berikutnya terdapat Fenty Beauty by Rihanna, yang juga memiliki jumlah loves yang cukup tinggi, diikuti oleh Anastasia Beverly Hills dan Charlotte Tilbury. Sementara itu, brand lain seperti The Ordinary, NARS, Dior, Urban Decay, Rare Beauty by Selena Gomez, dan Tarte juga masuk dalam sepuluh besar, namun dengan jumlah loves yang relatif lebih rendah dibandingkan dua brand teratas. Temuan ini menunjukkan bahwa beberapa brand tertentu memiliki daya tarik yang lebih kuat dan berhasil mendapatkan perhatian pengguna lebih besar di platform Sephora.

# %% [markdown]
# ### **Action**

# %% [markdown]
# Berdasarkan temuan tersebut, perusahaan dapat memanfaatkan popularitas brand dengan jumlah loves tinggi seperti Sephora Collection dan Fenty Beauty sebagai strategi utama dalam promosi atau kampanye pemasaran. Selain itu, brand dengan jumlah loves yang lebih rendah dalam daftar ini dapat ditingkatkan promosinya melalui kolaborasi promosi, rekomendasi produk, atau strategi pemasaran digital agar dapat menarik lebih banyak perhatian pengguna dan meningkatkan popularitasnya di platform.

# %% [markdown]
# ## **Pie Chart**

# %%
data_pie = df.groupby('primary_category')['loves_count'].sum().sort_values(ascending=False).head(5)

plt.figure(figsize=(10, 7))
plt.pie(
    data_pie,
    labels=data_pie.index,
    autopct='%1.1f%%',
    startangle=140,
    colors=sns.color_palette('pastel'),
    pctdistance=0.85,
)

plt.title('Top 5 Kategori Produk Berdasarkan Popularitas (Loves)')
plt.show()

# %% [markdown]
# ### **Insight**

# %% [markdown]
# Berdasarkan pie chart mengenai lima kategori produk teratas, terlihat bahwa kategori Makeup mendominasi popularitas dengan persentase mencapai 53,5%. Hal ini menunjukkan bahwa lebih dari separuh ketertarikan pengguna di platform Sephora terpusat pada produk riasan. Di posisi kedua, kategori Skincare memberikan kontribusi sebesar 27,3%, yang menunjukkan bahwa produk perawatan kulit juga memiliki tingkat popularitas yang cukup tinggi meskipun masih berada di bawah kategori Makeup.
#
# Sementara itu, kategori lainnya seperti Hair (8,4%), Fragrance (7,6%), dan Mini Size (3,2%) memiliki persentase yang jauh lebih kecil. Perbedaan ini menunjukkan bahwa ketertarikan pengguna di platform tersebut lebih banyak terfokus pada kategori Makeup dan Skincare, sementara kategori lainnya memiliki porsi popularitas yang relatif lebih rendah.

# %% [markdown]
# ### **Action**

# %% [markdown]
# Berdasarkan hasil analisis tersebut, perusahaan dapat lebih memfokuskan strategi pemasaran dan pengembangan produk pada kategori Makeup dan Skincare, karena kedua kategori ini memiliki tingkat popularitas yang paling tinggi di kalangan pengguna. Selain itu, kategori dengan persentase lebih rendah seperti Hair, Fragrance, dan Mini Size dapat ditingkatkan visibilitasnya melalui promosi khusus, paket bundling dengan produk populer, atau kampanye pemasaran yang lebih menarik. Dengan strategi tersebut, diharapkan minat pengguna terhadap kategori yang kurang populer juga dapat meningkat.

# %% [markdown]
# ## **Line Chart**

# %% [markdown]
# ### **Penjelasan**

# %% [markdown]
# Dalam penyusunan laporan ini, visualisasi Line Chart tidak digunakan karena dataset produk Sephora tidak memiliki variabel waktu seperti tanggal, bulan, atau tahun yang biasanya digunakan untuk melihat tren. Jika tetap digunakan, garis yang menghubungkan antar produk dapat menimbulkan kesalahan interpretasi, seolah-olah terdapat urutan atau hubungan tertentu antar produk. Oleh karena itu, analisis lebih difokuskan pada penggunaan Scatter Plot, Bubble Chart, dan Heatmap yang lebih sesuai untuk menggambarkan hubungan dan korelasi antar variabel produk.

# %% [markdown]
# ## **Histogram**

# %%
plt.figure(figsize=(10, 6))

sns.histplot(df['rating'], bins=10, kde=True, color='orange', edgecolor='black')

plt.title('Distribusi Rating Produk di Sephora', fontsize=14)
plt.xlabel('Rating (Skala 1-5)', fontsize=12)
plt.ylabel('Jumlah Produk', fontsize=12)

plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# ### **Insight**

# %% [markdown]
# Berdasarkan histogram distribusi rating produk di platform Sephora, terlihat bahwa sebagian besar produk memiliki rating yang cukup tinggi. Konsentrasi terbesar berada pada kisaran 4.0 hingga 4.7, yang menunjukkan bahwa mayoritas produk mendapatkan penilaian positif dari konsumen. Hal ini mengindikasikan bahwa secara umum produk yang tersedia di platform tersebut dinilai memiliki kualitas yang baik dan mampu memenuhi harapan pengguna.
#
# Distribusi pada grafik juga menunjukkan pola yang condong ke kiri (left-skewed), di mana jumlah produk dengan rating rendah relatif sangat sedikit dibandingkan dengan produk yang memiliki rating tinggi. Produk dengan rating di bawah 3.0 hampir tidak terlihat pada grafik. Kondisi ini menunjukkan bahwa hanya sebagian kecil produk yang mendapatkan penilaian kurang baik dari konsumen.
#
# Selain itu, tingginya jumlah produk dengan rating di atas 4.0 menunjukkan bahwa konsumen cenderung memberikan ulasan positif terhadap produk yang mereka gunakan. Hal ini dapat dipengaruhi oleh beberapa faktor, seperti kualitas produk yang baik, kepercayaan terhadap merek, serta pengalaman pengguna yang memuaskan setelah menggunakan produk tersebut.
#
# Secara keseluruhan, distribusi rating ini menunjukkan bahwa sebagian besar produk di platform Sephora memiliki tingkat kepuasan pelanggan yang tinggi. Rating yang baik juga dapat menjadi salah satu faktor penting yang memengaruhi keputusan pembelian konsumen, karena calon pembeli biasanya lebih percaya pada produk yang memiliki ulasan dan penilaian yang positif dari pengguna lain.

# %% [markdown]
# ### **Action**

# %% [markdown]
# Berdasarkan distribusi rating produk yang menunjukkan bahwa sebagian besar produk memiliki penilaian yang tinggi, terdapat beberapa langkah yang dapat dilakukan oleh perusahaan atau platform untuk memanfaatkan informasi tersebut. Salah satunya adalah dengan terus menjaga kualitas produk agar tingkat kepuasan pelanggan tetap tinggi. Konsistensi dalam menjaga kualitas sangat penting agar produk tetap mendapatkan penilaian positif dari konsumen. Selain itu, produk dengan rating tinggi juga dapat dimanfaatkan sebagai bagian dari strategi pemasaran, misalnya dengan menampilkan label seperti produk dengan ulasan terbaik atau rekomendasi pelanggan, sehingga dapat meningkatkan kepercayaan calon pembeli.
#
# Di sisi lain, meskipun jumlahnya relatif sedikit, produk dengan rating rendah tetap perlu mendapat perhatian. Perusahaan dapat meninjau kembali ulasan yang diberikan oleh pelanggan untuk mengetahui penyebab ketidakpuasan, seperti kualitas produk yang kurang sesuai, harga yang dianggap tidak sebanding dengan manfaat, atau pengalaman penggunaan yang kurang memuaskan. Informasi tersebut dapat menjadi bahan evaluasi untuk melakukan perbaikan produk di masa mendatang. Selain itu, perusahaan juga dapat mendorong pelanggan untuk memberikan ulasan setelah melakukan pembelian, sehingga data rating yang tersedia menjadi lebih lengkap dan dapat membantu konsumen lain dalam menentukan pilihan produk.

# %% [markdown]
# ## **BoxPlot**

# %%
top_categories = df['primary_category'].value_counts().head(5).index
df_top = df[df['primary_category'].isin(top_categories)]

plt.figure(figsize=(12, 7))

sns.boxplot(x='primary_category', y='rating', data=df_top,
            palette='viridis', order=top_categories, hue='primary_category', legend=False)

plt.title('Perbandingan Distribusi Rating pada 5 Kategori Produk Terpopuler', fontsize=16)
plt.xlabel('Kategori Produk', fontsize=12)
plt.ylabel('Skala Rating (1-5)', fontsize=12)

plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Insight**

# %% [markdown]
# Visualisasi boxplot pada lima kategori produk terpopuler menunjukkan bahwa median rating berada pada angka yang konsisten tinggi, yaitu di atas 4.0. Namun, pada semua kategori tersebut terdapat distribusi outliers yang signifikan di sisi bawah (nilai rating rendah). Keberadaan outliers ini merepresentasikan variasi kualitas produk yang nyata di pasar, di mana terdapat segmen produk tertentu yang gagal memenuhi ekspektasi konsumen, meskipun kategori secara keseluruhan memiliki performa yang baik.
#
# Pola distribusi ini mengonfirmasi bahwa kepuasan pelanggan di platform Sephora bersifat beragam. Oleh karena itu, outliers tidak diperlakukan sebagai kesalahan data, melainkan sebagai informasi strategis untuk mengidentifikasi produk-produk yang memerlukan evaluasi kualitas dan penyesuaian strategi pemasaran. Analisis ini menegaskan pentingnya pengawasan terhadap produk dengan performa rendah guna menjaga standar kualitas platform secara keseluruhan.

# %% [markdown]
# ### **Action**

# %% [markdown]
# Berdasarkan distribusi rating dan keberadaan outliers, beberapa tindakan dapat dilakukan untuk meningkatkan kualitas dan performa produk. Produk dengan rating rendah perlu dievaluasi melalui ulasan pelanggan untuk mengidentifikasi penyebab ketidakpuasan, sehingga perbaikan atau pengembangan produk dapat dilakukan agar lebih sesuai dengan harapan konsumen. Produk dengan rating tinggi dapat ditonjolkan sebagai unggulan melalui strategi pemasaran, misalnya dengan label “Top Rated” atau “Customer Favorite”, sementara produk dengan performa rendah tetap dipantau secara berkala untuk memastikan standar kualitasnya selalu ditingkatkan. Selain itu, mendorong konsumen memberikan ulasan secara rutin akan membantu menjaga data rating tetap akurat dan relevan, sehingga perusahaan dapat mengambil keputusan strategis yang lebih tepat berdasarkan kondisi pasar yang nyata.

# %% [markdown]
# ## **Scatter Plot**

# %%
plt.figure(figsize=(10, 6))

sns.scatterplot(x='rating', y='loves_count', hue='primary_category', data=df_top, alpha=0.6)

plt.title('Hubungan antara Rating dan Jumlah Loves (Popularitas)', fontsize=14)
plt.xlabel('Rating (Kualitas)', fontsize=12)
plt.ylabel('Loves Count (Popularitas)', fontsize=12)

plt.legend(title='Kategori Produk', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Insight**

# %% [markdown]
# Berdasarkan scatter plot hubungan antara rating dan jumlah loves (popularitas), terlihat bahwa sebagian besar produk memiliki rating pada rentang 3,5 hingga 4,7. Titik-titik pada grafik menunjukkan bahwa produk dengan rating tinggi cenderung memiliki jumlah loves yang lebih banyak, namun hubungan tersebut tidak terlalu kuat karena terdapat banyak produk dengan rating tinggi tetapi memiliki jumlah loves yang rendah. Selain itu, sebagian besar data terkonsentrasi pada jumlah loves yang rendah, sementara hanya beberapa produk yang memiliki jumlah loves sangat tinggi sehingga membentuk outlier pada grafik. Hal ini menunjukkan bahwa popularitas produk tidak hanya dipengaruhi oleh rating, tetapi kemungkinan juga dipengaruhi oleh faktor lain seperti jumlah review, brand, atau kategori produk.

# %% [markdown]
# ### **Action**

# %% [markdown]
# Berdasarkan hasil analisis tersebut, strategi ke depan tidak hanya perlu berfokus pada peningkatan rating produk, tetapi juga pada upaya meningkatkan popularitasnya. Perusahaan dapat lebih aktif mempromosikan produk yang sudah memiliki rating tinggi namun jumlah loves-nya masih rendah, misalnya melalui promosi, iklan, atau mendorong lebih banyak ulasan dari pelanggan agar produk lebih dikenal oleh pengguna lain. Selain itu, produk-produk yang memiliki jumlah loves sangat tinggi juga perlu dianalisis lebih lanjut untuk mengetahui faktor yang memengaruhi popularitasnya, seperti kekuatan brand atau tren kategori produk. Informasi tersebut dapat dijadikan referensi untuk mengembangkan strategi pemasaran pada produk lain agar minat konsumen turut meningkat.

# %% [markdown]
# ## **Bubble Chart**

# %%
plt.figure(figsize=(12, 8))

sns.scatterplot(x='rating', y='loves_count', size='reviews', hue='primary_category',
                data=df_top, sizes=(50, 1000), alpha=0.6, palette='viridis')

plt.title('Hubungan Rating, Popularitas (Loves), dan Jumlah Ulasan (Reviews)', fontsize=16)
plt.xlabel('Rating (Kualitas)', fontsize=12)
plt.ylabel('Loves Count (Popularitas)', fontsize=12)

plt.grid(True, linestyle='--', alpha=0.5)
plt.legend(title='Kategori & Ukuran Review', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Insight**

# %% [markdown]
# Berdasarkan bubble chart yang menunjukkan hubungan antara rating, jumlah loves (popularitas), dan jumlah reviews, terlihat bahwa sebagian besar produk memiliki rating pada kisaran 3,5 hingga 4,7. Produk dengan rating yang lebih tinggi cenderung memiliki jumlah loves yang lebih besar, meskipun hubungan tersebut tidak sepenuhnya konsisten karena masih terdapat produk dengan rating tinggi tetapi popularitasnya rendah. Selain itu, ukuran bubble menunjukkan bahwa produk dengan jumlah reviews yang lebih banyak umumnya juga memiliki popularitas yang lebih tinggi, yang terlihat dari beberapa bubble besar yang berada pada area loves tinggi. Hal ini mengindikasikan bahwa jumlah ulasan pelanggan dapat berperan dalam meningkatkan popularitas produk, karena produk yang sering diulas cenderung lebih terlihat dan menarik perhatian pengguna lain.

# %% [markdown]
# ### **Action**

# %% [markdown]
# Berdasarkan hasil dari chart tersebut, perusahaan dapat meningkatkan popularitas produk dengan mendorong lebih banyak ulasan dari pelanggan, misalnya melalui program review, promosi, atau insentif bagi pembeli yang memberikan feedback. Selain itu, produk dengan rating tinggi namun jumlah reviews dan loves yang masih rendah dapat diprioritaskan untuk dipromosikan agar visibilitasnya meningkat. Dengan meningkatkan jumlah ulasan dan eksposur produk, peluang produk untuk menjadi lebih populer di platform juga dapat meningkat.

# %% [markdown]
# ## **HeatMap**

# %%
plt.figure(figsize=(8, 6))

sns.heatmap(data=df[['rating', 'loves_count', 'reviews']].corr(),
            annot=True,
            cmap='viridis',
            fmt='.2f')

plt.title('Heatmap Korelasi Rating, Loves, dan Reviews', fontsize=14)
plt.show()

# %% [markdown]
# ### **Insight**

# %% [markdown]
# Berdasarkan heatmap korelasi, terlihat hubungan yang menarik antara ketiga variabel utama. Nilai korelasi antara rating dan loves (0,04) serta rating dan reviews (0,07) menunjukkan hubungan yang sangat lemah. Hal ini menunjukkan bahwa rating yang tinggi tidak selalu diikuti oleh meningkatnya popularitas produk maupun banyaknya ulasan dari pengguna.
#
# Di sisi lain, terdapat hubungan yang cukup kuat antara loves dan reviews dengan nilai korelasi sebesar 0,68. Hubungan ini mengindikasikan bahwa produk yang memiliki jumlah ulasan lebih banyak cenderung memiliki tingkat popularitas yang lebih tinggi. Dengan kata lain, aktivitas ulasan pelanggan dapat berperan dalam meningkatkan visibilitas dan ketertarikan pengguna terhadap suatu produk.

# %% [markdown]
# ### **Action**

# %% [markdown]
# Berdasarkan hasil analisis korelasi, perusahaan sebaiknya lebih memfokuskan strategi pada peningkatan interaksi pelanggan, terutama dalam mendorong lebih banyak ulasan (reviews). Hal ini dapat dilakukan melalui pemberian insentif ulasan, program feedback pelanggan, atau kampanye yang mengajak pembeli untuk membagikan pengalaman mereka setelah menggunakan produk. Selain itu, produk yang telah memiliki banyak ulasan dapat lebih ditonjolkan dalam promosi karena berpotensi memiliki tingkat popularitas yang lebih tinggi. Dengan meningkatnya jumlah interaksi melalui ulasan, visibilitas dan ketertarikan pengguna terhadap produk juga dapat ikut meningkat.

# %% [markdown]
# # **Menyimpan Dataset**

# %%
df.to_csv('[bersih]sephora_product_popularity.csv', index=False)
